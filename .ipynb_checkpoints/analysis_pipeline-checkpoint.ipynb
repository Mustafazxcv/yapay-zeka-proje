# %% [markdown]
# # Haber Başlığı Ödev Projesi
#
# Bu notebook, **veri çekme scriptlerinden sonra** çalışır.
#
# ## Öğrenciler
# - Mustafa Mete / 2202131015
# - Emine Avcu / 2202131006

# %% [markdown]
# ## 2. Veri Seti Seçimi ve Raporlama
#
# ### Kaynak
# - Veri seti dosyası: `data/all/headlines_all.json`
# - Veri toplama yöntemi: Python botları ile API + web/RSS tabanlı toplama, ardından tek havuzda birleştirme (`append-mode`).
# - Kullanılan kaynaklar ve URL'ler:
#   - NewsData API: `https://newsdata.io/api/1/news`
#   - NewsAPI (Top Headlines / Sources): `https://newsapi.org/`
#   - Google News RSS Search: `https://news.google.com/rss/search`
#   - Google Search (web sonuçları): `https://www.google.com/search`
# - Not: Toplanan kayıtlar `title`, `source`, `link`, `pubDate`, `fetchedAt` alanlarıyla standartlaştırılmıştır.
#
# ### Boyut
# - Toplam doküman (ham kayıt) sayısı: **2805**
# - Orijinal dosya formatı: **JSON**
# - Orijinal dosya boyutu: **1.449 MB** (`headlines_all.json`)
# - Eşlenik CSV dosyası: **1.187 MB** (`headlines_all.csv`)
#
# ### Sütun Yapısı
# Aşağıdaki kolonlar modelleme için anlamlı ve düzenli bir yapıda tutulmuştur:
#
# - `title`: Haber başlığı (ham metin)
# - `source`: Haber kaynağı/site adı
# - `link`: Haber URL'si
# - `pubDate`: Yayın tarihi
# - `fetchedAt`: Verinin çekildiği zaman damgası
#
# Notebook içindeki normalizasyon adımında ek olarak aşağıdaki alan üretilmiştir:
# - `normalized_title`: Temizlenmiş/normalize edilmiş başlık metni
#
# ### CSV Düzenleme Notu
# - UTF-8 kodlama kullanılmıştır.
# - Alan adları sabittir ve tüm kayıtlar aynı şemaya göre yazılmıştır.
# - Tekrarlı kayıtlar `title+source+link+pubDate` anahtarına göre temizlenmiştir.
# - Bu düzenli yapı, sonraki model eğitimi adımları için doğrudan kullanılabilir durumdadır.

# %%
import csv
import html
import json
import re
import unicodedata
from pathlib import Path
from pprint import pprint

import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Tum pipeline parametreleri tek bir yapida tutuluyor.
CONFIG = {
    'input_json': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/all/headlines_all.json'),
    'normalized_out_csv': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/processed/all/headlines_normalized_all.csv'),
    'normalized_out_json': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/processed/all/headlines_normalized_all.json'),
    'pairs_out_csv': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/results/all/duplicate_pairs_all.csv'),
    'pairs_out_json': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/results/all/duplicate_pairs_all.json'),
    'threshold': 0.85,
    'language': 'english'
}

# %%
# Parametreleri acik ve okunabilir sekilde yazdir.
print('=== PIPELINE PARAMETRELERI ===')
print(f"input_json          : {CONFIG['input_json']}")
print(f"normalized_out_csv  : {CONFIG['normalized_out_csv']}")
print(f"normalized_out_json : {CONFIG['normalized_out_json']}")
print(f"pairs_out_csv       : {CONFIG['pairs_out_csv']}")
print(f"pairs_out_json      : {CONFIG['pairs_out_json']}")
print(f"threshold           : {CONFIG['threshold']:.2f}")
print(f"language            : {CONFIG['language']}")
# Out:
# === PIPELINE PARAMETRELERI ===
# input_json          : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\all\headlines_all.json
# normalized_out_csv  : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# normalized_out_json : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json
# pairs_out_csv       : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv
# pairs_out_json      : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json
# threshold           : 0.85
# language            : english

# %%
# Gerekli NLTK corpus'unu indir.
# Not: Daha once indirildiyse tekrar indirmez.
nltk.download('stopwords', quiet=True)

# Dile gore stopwords seti olustur.
LANG_STOPWORDS = set(stopwords.words(CONFIG['language']))
print(f'Stopwords yuklendi. Toplam: {len(LANG_STOPWORDS)}')
# Out:
# Stopwords yuklendi. Toplam: 198

# %% [markdown]
# ## 3. Ön İşleme (Pre-processing) Aşamaları
#
# Bu bölümde aşağıdaki adımlar sırasıyla uygulanmıştır:
# 1. Genel içerik temizliği (HTML, özel karakter, sayı, gereksiz semboller)
# 2. Lowercasing
# 3. Tokenization (cümle yapısı korunarak)
# 4. Stop Word Removal
# 5. Lemmatization
# 6. Stemming
#
# Her adım için `Önce/Sonra` çıktıları üretilmektedir.

# %%
# NLTK kutuphaneleri (tokenization, stopword, lemmatization, stemming) icin gerekli veri paketleri.
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize  # NLTK: sentence/word tokenization
from nltk.corpus import stopwords  # NLTK: stopword removal
from nltk.stem import WordNetLemmatizer, PorterStemmer  # NLTK: lemmatization + stemming
import re  # re: regex tabanli temizlik
import html  # html: HTML entity cozumleme

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

# Dile ozgu stopword seti (NLTK)
EN_STOPWORDS = set(stopwords.words('english'))
LEMMATIZER = WordNetLemmatizer()
STEMMER = PorterStemmer()

# Veri setinden metinleri al (headlines_all.json)
with CONFIG['input_json'].open('r', encoding='utf-8') as f:
    pp_raw_records = json.load(f)

# Pre-processing gosterimi icin veri setinden ilk dolu 5 basligi sec
dataset_texts = []
for item in pp_raw_records:
    title = (item.get('title') or '').strip()
    if title:
        dataset_texts.append(title)
    if len(dataset_texts) == 5:
        break

print('Pre-processing veri seti hazirlandi. Toplam secilen kayit:', len(dataset_texts))
# Out:
# Pre-processing veri seti hazirlandi. Toplam secilen kayit: 5

# %%
# ==============================
# 1) Genel Icerik Temizlik (re + html)
# ==============================
def clean_general_content(text: str) -> str:
    # html kutuphanesi: HTML entity (ornegin &amp;) cozumleme
    text = html.unescape(text)

    # re kutuphanesi: HTML etiketleri temizleme
    text = re.sub(r'<[^>]+>', ' ', text)

    # re kutuphanesi: URL temizleme
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)

    # re kutuphanesi: sayi temizleme
    text = re.sub(r'\d+', ' ', text)

    # re kutuphanesi: noktalama disi ozel karakter/simge temizleme
    # Cumle noktalari (. ! ?) korunuyor; sentence tokenization icin gerekli.
    text = re.sub(r"[^\w\s\.!\?]", ' ', text)

    # Fazla bosluklari sadele
    text = re.sub(r'\s+', ' ', text).strip()
    return text


# ==============================
# 2) Lowercasing
# ==============================
def to_lowercase(text: str) -> str:
    return text.lower()


# ==============================
# 3) Tokenization (NLTK)
# ==============================
def tokenize_with_sentences(text: str):
    # NLTK sent_tokenize: Cumleleri korur
    sentences = sent_tokenize(text)

    # NLTK word_tokenize: Her cumleyi kelimelere ayirir
    tokenized_sentences = []
    for sent in sentences:
        tokens = word_tokenize(sent)
        # Cumle sonu noktalama tokenlarini at
        tokens = [tok for tok in tokens if tok not in {'.', '!', '?', ',', ';', ':', '"', "'", '``', "''"}]
        tokenized_sentences.append(tokens)
    return sentences, tokenized_sentences


# ==============================
# 4) Stop Word Removal (NLTK)
# ==============================
def remove_stopwords(tokenized_sentences):
    cleaned = []
    for sent_tokens in tokenized_sentences:
        cleaned.append([tok for tok in sent_tokens if tok.lower() not in EN_STOPWORDS])
    return cleaned


# ==============================
# 5) Lemmatization (NLTK WordNetLemmatizer)
# ==============================
def lemmatize_tokens(tokenized_sentences):
    lemmatized = []
    for sent_tokens in tokenized_sentences:
        lemmatized.append([LEMMATIZER.lemmatize(tok.lower()) for tok in sent_tokens])
    return lemmatized


# ==============================
# 6) Stemming (NLTK PorterStemmer)
# ==============================
def stem_tokens(tokenized_sentences):
    stemmed = []
    for sent_tokens in tokenized_sentences:
        stemmed.append([STEMMER.stem(tok.lower()) for tok in sent_tokens])
    return stemmed


# ==============================
# ADIM ADIM ONCE/SONRA GOSTERIMI (VERI SETINDEN)
# ==============================
for idx, raw_text in enumerate(dataset_texts, start=1):
    print(f"\n{'=' * 80}")
    print(f"VERI SETI KAYDI {idx}")
    print(f"{'=' * 80}")

    # 1) Genel Icerik Temizlik
    cleaned = clean_general_content(raw_text)
    print("\n[1] Genel Icerik Temizlik (re + html)")
    print("ONCE :", raw_text)
    print("SONRA:", cleaned)

    # 2) Lowercasing
    lowered = to_lowercase(cleaned)
    print("\n[2] Lowercasing")
    print("ONCE :", cleaned)
    print("SONRA:", lowered)

    # 3) Tokenization (cumleleri koruyarak)
    sentences_before, tokenized = tokenize_with_sentences(lowered)
    print("\n[3] Tokenization (NLTK sent_tokenize + word_tokenize)")
    print("ONCE (Cumleler):", sentences_before)
    print("SONRA (Tokenlar):", tokenized)

    # 4) Stop Word Removal
    no_stop = remove_stopwords(tokenized)
    print("\n[4] Stop Word Removal (NLTK stopwords)")
    print("ONCE :", tokenized)
    print("SONRA:", no_stop)

    # 5) Lemmatization
    lemmatized = lemmatize_tokens(no_stop)
    print("\n[5] Lemmatization (NLTK WordNetLemmatizer)")
    print("ONCE :", no_stop)
    print("SONRA:", lemmatized)

    # 6) Stemming
    stemmed = stem_tokens(lemmatized)
    print("\n[6] Stemming (NLTK PorterStemmer)")
    print("ONCE :", lemmatized)
    print("SONRA:", stemmed)

print("\nTum pre-processing adimlari tamamlandi.")
# Out:
# ================================================================================
# VERI SETI KAYDI 1
# ================================================================================
#
# [1] Genel Icerik Temizlik (re + html)
# ONCE : U.S. stocks clock best month since 2020 as Wall Street shakes off Iran oil shock
# SONRA: U.S. stocks clock best month since as Wall Street shakes off Iran oil shock
#
# [2] Lowercasing
# ONCE : U.S. stocks clock best month since as Wall Street shakes off Iran oil shock
# SONRA: u.s. stocks clock best month since as wall street shakes off iran oil shock
#
# [3] Tokenization (NLTK sent_tokenize + word_tokenize)
# ONCE (Cumleler): ['u.s. stocks clock best month since as wall street shakes off iran oil shock']
# SONRA (Tokenlar): [['u.s.', 'stocks', 'clock', 'best', 'month', 'since', 'as', 'wall', 'street', 'shakes', 'off', 'iran', 'oil', 'shock']]
#
# [4] Stop Word Removal (NLTK stopwords)
# ONCE : [['u.s.', 'stocks', 'clock', 'best', 'month', 'since', 'as', 'wall', 'street', 'shakes', 'off', 'iran', 'oil', 'shock']]
# SONRA: [['u.s.', 'stocks', 'clock', 'best', 'month', 'since', 'wall', 'street', 'shakes', 'iran', 'oil', 'shock']]
#
# [5] Lemmatization (NLTK WordNetLemmatizer)
# ONCE : [['u.s.', 'stocks', 'clock', 'best', 'month', 'since', 'wall', 'street', 'shakes', 'iran', 'oil', 'shock']]
# SONRA: [['u.s.', 'stock', 'clock', 'best', 'month', 'since', 'wall', 'street', 'shake', 'iran', 'oil', 'shock']]
#
# [6] Stemming (NLTK PorterStemmer)
# ONCE : [['u.s.', 'stock', 'clock', 'best', 'month', 'since', 'wall', 'street', 'shake', 'iran', 'oil', 'shock']]
# SONRA: [['u.s.', 'stock', 'clock', 'best', 'month', 'sinc', 'wall', 'street', 'shake', 'iran', 'oil', 'shock']]
#
# ================================================================================
# VERI SETI KAYDI 2
# ================================================================================
#
# [1] Genel Icerik Temizlik (re + html)
# ONCE : FAA chief predicts fewer air traffic control delays this summer
# SONRA: FAA chief predicts fewer air traffic control delays this summer
#
# [2] Lowercasing
# ONCE : FAA chief predicts fewer air traffic control delays this summer
# SONRA: faa chief predicts fewer air traffic control delays this summer
#
# [3] Tokenization (NLTK sent_tokenize + word_tokenize)
# ONCE (Cumleler): ['faa chief predicts fewer air traffic control delays this summer']
# SONRA (Tokenlar): [['faa', 'chief', 'predicts', 'fewer', 'air', 'traffic', 'control', 'delays', 'this', 'summer']]
#
# [4] Stop Word Removal (NLTK stopwords)
# ONCE : [['faa', 'chief', 'predicts', 'fewer', 'air', 'traffic', 'control', 'delays', 'this', 'summer']]
# SONRA: [['faa', 'chief', 'predicts', 'fewer', 'air', 'traffic', 'control', 'delays', 'summer']]
#
# [5] Lemmatization (NLTK WordNetLemmatizer)
# ONCE : [['faa', 'chief', 'predicts', 'fewer', 'air', 'traffic', 'control', 'delays', 'summer']]
# SONRA: [['faa', 'chief', 'predicts', 'fewer', 'air', 'traffic', 'control', 'delay', 'summer']]
#
# [6] Stemming (NLTK PorterStemmer)
# ONCE : [['faa', 'chief', 'predicts', 'fewer', 'air', 'traffic', 'control', 'delay', 'summer']]
# SONRA: [['faa', 'chief', 'predict', 'fewer', 'air', 'traffic', 'control', 'delay', 'summer']]
#
# ================================================================================
# VERI SETI KAYDI 3
# ================================================================================
#
# [1] Genel Icerik Temizlik (re + html)
# ONCE : Stephen King’s 2 New Shows In 2026 Will Tell The Same Dark Story
# SONRA: Stephen King s New Shows In Will Tell The Same Dark Story
#
# [2] Lowercasing
# ONCE : Stephen King s New Shows In Will Tell The Same Dark Story
# SONRA: stephen king s new shows in will tell the same dark story
#
# [3] Tokenization (NLTK sent_tokenize + word_tokenize)
# ONCE (Cumleler): ['stephen king s new shows in will tell the same dark story']
# SONRA (Tokenlar): [['stephen', 'king', 's', 'new', 'shows', 'in', 'will', 'tell', 'the', 'same', 'dark', 'story']]
#
# [4] Stop Word Removal (NLTK stopwords)
# ONCE : [['stephen', 'king', 's', 'new', 'shows', 'in', 'will', 'tell', 'the', 'same', 'dark', 'story']]
# SONRA: [['stephen', 'king', 'new', 'shows', 'tell', 'dark', 'story']]
#
# [5] Lemmatization (NLTK WordNetLemmatizer)
# ONCE : [['stephen', 'king', 'new', 'shows', 'tell', 'dark', 'story']]
# SONRA: [['stephen', 'king', 'new', 'show', 'tell', 'dark', 'story']]
#
# [6] Stemming (NLTK PorterStemmer)
# ONCE : [['stephen', 'king', 'new', 'show', 'tell', 'dark', 'story']]
# SONRA: [['stephen', 'king', 'new', 'show', 'tell', 'dark', 'stori']]
#
# ================================================================================
# VERI SETI KAYDI 4
# ================================================================================
#
# [1] Genel Icerik Temizlik (re + html)
# ONCE : Tennessee man uses lasers to make the world’s thinnest car
# SONRA: Tennessee man uses lasers to make the world s thinnest car
#
# [2] Lowercasing
# ONCE : Tennessee man uses lasers to make the world s thinnest car
# SONRA: tennessee man uses lasers to make the world s thinnest car
#
# [3] Tokenization (NLTK sent_tokenize + word_tokenize)
# ONCE (Cumleler): ['tennessee man uses lasers to make the world s thinnest car']
# SONRA (Tokenlar): [['tennessee', 'man', 'uses', 'lasers', 'to', 'make', 'the', 'world', 's', 'thinnest', 'car']]
#
# [4] Stop Word Removal (NLTK stopwords)
# ONCE : [['tennessee', 'man', 'uses', 'lasers', 'to', 'make', 'the', 'world', 's', 'thinnest', 'car']]
# SONRA: [['tennessee', 'man', 'uses', 'lasers', 'make', 'world', 'thinnest', 'car']]
#
# [5] Lemmatization (NLTK WordNetLemmatizer)
# ONCE : [['tennessee', 'man', 'uses', 'lasers', 'make', 'world', 'thinnest', 'car']]
# SONRA: [['tennessee', 'man', 'us', 'laser', 'make', 'world', 'thinnest', 'car']]
#
# [6] Stemming (NLTK PorterStemmer)
# ONCE : [['tennessee', 'man', 'us', 'laser', 'make', 'world', 'thinnest', 'car']]
# SONRA: [['tennesse', 'man', 'us', 'laser', 'make', 'world', 'thinnest', 'car']]
#
# ================================================================================
# VERI SETI KAYDI 5
# ================================================================================
#
# [1] Genel Icerik Temizlik (re + html)
# ONCE : Chicago police officer John Bartholomew's accused killer ordered held until murder trial
# SONRA: Chicago police officer John Bartholomew s accused killer ordered held until murder trial
#
# [2] Lowercasing
# ONCE : Chicago police officer John Bartholomew s accused killer ordered held until murder trial
# SONRA: chicago police officer john bartholomew s accused killer ordered held until murder trial
#
# [3] Tokenization (NLTK sent_tokenize + word_tokenize)
# ONCE (Cumleler): ['chicago police officer john bartholomew s accused killer ordered held until murder trial']
# SONRA (Tokenlar): [['chicago', 'police', 'officer', 'john', 'bartholomew', 's', 'accused', 'killer', 'ordered', 'held', 'until', 'murder', 'trial']]
#
# [4] Stop Word Removal (NLTK stopwords)
# ONCE : [['chicago', 'police', 'officer', 'john', 'bartholomew', 's', 'accused', 'killer', 'ordered', 'held', 'until', 'murder', 'trial']]
# SONRA: [['chicago', 'police', 'officer', 'john', 'bartholomew', 'accused', 'killer', 'ordered', 'held', 'murder', 'trial']]
#
# [5] Lemmatization (NLTK WordNetLemmatizer)
# ONCE : [['chicago', 'police', 'officer', 'john', 'bartholomew', 'accused', 'killer', 'ordered', 'held', 'murder', 'trial']]
# SONRA: [['chicago', 'police', 'officer', 'john', 'bartholomew', 'accused', 'killer', 'ordered', 'held', 'murder', 'trial']]
#
# [6] Stemming (NLTK PorterStemmer)
# ONCE : [['chicago', 'police', 'officer', 'john', 'bartholomew', 'accused', 'killer', 'ordered', 'held', 'murder', 'trial']]
# SONRA: [['chicago', 'polic', 'offic', 'john', 'bartholomew', 'accus', 'killer', 'order', 'held', 'murder', 'trial']]
#
# Tum pre-processing adimlari tamamlandi.

# %%
VERBOSE_NORMALIZE = True

# Baslik sonundaki kaynak etiketlerini temizler.
def strip_source_suffix(title: str) -> str:
    title = re.sub(r'\s*-\s*[^-]{2,80}$', '', title).strip()
    title = re.sub(r'\s*\|\s*[^|]{2,80}$', '', title).strip()
    return title

# Turkce karakterlerin ASCII benzeri formunu alir.
def remove_accents(text: str) -> str:
    normalized = unicodedata.normalize('NFKD', text)
    return ''.join(ch for ch in normalized if not unicodedata.combining(ch))

NOISE_TERMS = {
    'live', 'update', 'updates', 'video', 'photos', 'podcast', 'analysis',
    'opinion', 'exclusive', 'new', 'breaking', 'watch', 'report', 'latest'
}

# Tek bir basligi normalize eder.
def normalize_title(text: str) -> str:
    original = text

    text = html.unescape(text)
    text = strip_source_suffix(text)
    text = remove_accents(text).lower()
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)
    text = re.sub(r'\[[^\]]*\]|\([^\)]*\)', ' ', text)
    text = re.sub(r'[^\w\s]', ' ', text)

    tokens = re.findall(r'[a-z0-9]+', text)

    cleaned_tokens = []
    for token in tokens:
        if token in LANG_STOPWORDS:
            continue
        if token in NOISE_TERMS:
            continue
        if token.isdigit():
            continue
        if len(token) < 3:
            continue
        cleaned_tokens.append(token)

    result = ' '.join(cleaned_tokens).strip()

    #if VERBOSE_NORMALIZE:
        #print(f"[normalize_title] Orijinal: {original}")
        #print(f"[normalize_title] Token sayisi: {len(tokens)}")
        #print(f"[normalize_title] Sonuc: {result}")

    return result


def write_csv(path: Path, rows, fieldnames):
    print(f"[write_csv] Yaziliyor: {path}")
    print(f"[write_csv] Satir sayisi: {len(rows)}")

    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open('w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

    print("[write_csv] Tamamlandi")


def write_json(path: Path, data):
    print(f"[write_json] Yaziliyor: {path}")
    print(f"[write_json] Kayit sayisi: {len(data) if isinstance(data, list) else 'N/A'}")

    path.parent.mkdir(parents=True, exist_ok=True)

    path.write_text(
        json.dumps(data, ensure_ascii=False, indent=2),
        encoding='utf-8'
    )

    print("[write_json] Tamamlandi")


print('[4/11] Yardimci fonksiyonlar hazirlandi.')
# Out:
# [4/11] Yardimci fonksiyonlar hazirlandi.

# %%
input_path = CONFIG['input_json']
if not input_path.exists():
    raise FileNotFoundError(f'Girdi dosyasi bulunamadi: {input_path}')

raw_records = json.loads(input_path.read_text(encoding='utf-8'))
if not isinstance(raw_records, list):
    raise ValueError('Girdi JSON formati hatali. Liste bekleniyor.')

print(f'Ham kayit sayisi: {len(raw_records)}')
# Out:
# Ham kayit sayisi: 2805

# %%
normalized_records = []

for item in raw_records:
    # Bos veya eksik title kayitlarini atla.
    title = (item.get('title') or '').strip()
    if not title:
        continue

    normalized = normalize_title(title)
    if not normalized:
        continue

    normalized_records.append(
        {
            'title': title,
            'normalized_title': normalized,
            'source': item.get('source') or '',
            'link': item.get('link') or '',
            'pubDate': item.get('pubDate') or '',
        }
    )

print(f'Normalize kayit sayisi: {len(normalized_records)}')
print('Ornek normalize kayit:')
pprint(normalized_records[:2])
# Out:
# Normalize kayit sayisi: 2798
# Ornek normalize kayit:
# [{'link': 'https://www.marketwatch.com/bulletins/redirect/go?g=dab30966-8cf2-4a64-ba38-bbf711571f2f&mod=mw_rss_bulletins',
#   'normalized_title': 'stocks clock best month since wall street shakes iran '
#                       'oil shock',
#   'pubDate': '2026-04-30 21:06:53',
#   'source': 'marketwatch',
#   'title': 'U.S. stocks clock best month since 2020 as Wall Street shakes off '
#            'Iran oil shock'},
#  {'link': 'https://us.headtopics.com/news/faa-chief-predicts-fewer-air-traffic-control-delays-this-82875820',
#   'normalized_title': 'faa chief predicts fewer air traffic control delays '
#                       'summer',
#   'pubDate': '2026-04-30 21:06:40',
#   'source': 'headtopics',
#   'title': 'FAA chief predicts fewer air traffic control delays this summer'}]

# %%
write_csv(
    CONFIG['normalized_out_csv'],
    normalized_records,
    fieldnames=['title', 'normalized_title', 'source', 'link', 'pubDate'],
)
write_json(CONFIG['normalized_out_json'], normalized_records)

print(f"Normalize CSV kaydedildi: {CONFIG['normalized_out_csv']}")
print(f"Normalize JSON kaydedildi: {CONFIG['normalized_out_json']}")
# Out:
# [write_csv] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# [write_csv] Satir sayisi: 2798
# [write_csv] Tamamlandi
# [write_json] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json
# [write_json] Kayit sayisi: 2798
# [write_json] Tamamlandi
# Normalize CSV kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# Normalize JSON kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json

# %%
if len(normalized_records) < 2:
    raise ValueError('Yeterli veri yok. En az 2 baslik gerekli.')

titles = [r['normalized_title'] for r in normalized_records]
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
matrix = vectorizer.fit_transform(titles)
sim_matrix = cosine_similarity(matrix)

print(f'TFIDF matrix boyutu: {matrix.shape}')
print(f'Similarity matrix boyutu: {sim_matrix.shape}')
# Out:
# TFIDF matrix boyutu: (2798, 22360)
# Similarity matrix boyutu: (2798, 2798)

# %%
pairs = []
n = len(normalized_records)
threshold = CONFIG['threshold']

for i in range(n):
    for j in range(i + 1, n):
        score = float(sim_matrix[i, j])
        if score < threshold:
            continue

        a = normalized_records[i]
        b = normalized_records[j]
        source_a = (a['source'] or '').strip().lower()
        source_b = (b['source'] or '').strip().lower()
        link_a = (a['link'] or '').strip().lower()
        link_b = (b['link'] or '').strip().lower()


        if source_a and source_b and source_a == source_b:
            continue
        if link_a and link_b and link_a == link_b:
            continue

        pairs.append(
            {
                'title_1': a['title'],
                'title_2': b['title'],
                'normalized_title_1': a['normalized_title'],
                'normalized_title_2': b['normalized_title'],
                'similarity': f'{score:.4f}',
                'source_1': a['source'],
                'source_2': b['source'],
                'link_1': a['link'],
                'link_2': b['link'],
                'pubDate_1': a['pubDate'],
                'pubDate_2': b['pubDate'],
            }
        )

print(f'Bulunan duplicate cift sayisi: {len(pairs)}')
print('Ilk 3 sonuc:')
pprint(pairs[:3])
# Out:
# Bulunan duplicate cift sayisi: 161
# Ilk 3 sonuc:
# [{'link_1': 'https://news.mongabay.com/2026/04/in-guatemala-new-ai-technology-will-be-listening-for-illegal-deforestation/',
#   'link_2': 'https://news.google....?oc=5',
#   'normalized_title_1': 'guatemala technology listening illegal deforestation',
#   'normalized_title_2': 'guatemala technology listening illegal deforestation '
#                         'news',
#   'pubDate_1': '2026-04-30 21:05:18',
#   'pubDate_2': 'Thu, 30 Apr 2026 21:06:18 GMT',
#   'similarity': '0.9181',
#   'source_1': 'mongabay',
#   'source_2': 'news - Mongabay',
#   'title_1': 'In Guatemala, new AI technology will be ‘listening’ for illegal '
#              'deforestation',
#   'title_2': 'In Guatemala, new AI technology will be ‘listening’ for illegal '
#              'deforestation - news - Mongabay'},
#  {'link_1': 'https://www.benzinga.com/pressreleases/26/04/g52199923/fairfax-india-holdings-corporation-first-quarter-financial-results',
#   'link_2': 'https://www.globenewswire.com/news-release/2026/04/30/3285558/0/en/Fairfax-India-Holdings-Corporation-First-Quarter-Financial-Results.html',
#   'normalized_title_1': 'fairfax india holdings corporation first quarter '
#                         'financial results',
#   'normalized_title_2': 'fairfax india holdings corporation first quarter '
#                         'financial results',
#   'pubDate_1': '2026-04-30 21:05:00',
#   'pubDate_2': '2026-04-30 21:05:00',
#   'similarity': '1.0000',
#   'source_1': 'benzinga',
#   'source_2': 'globenewswire',
#   'title_1': 'Fairfax India Holdings Corporation: First Quarter Financial '
#              'Results',
#   'title_2': 'Fairfax India Holdings Corporation: First Quarter Financial '
#              'Results'},
#  {'link_1': 'https://utulsa.edu/news/bis-capstone-projects-deliver-technology-solutions-for-tulsa-nonprofits/',
#   'link_2': 'https://news.google.com/rss/articles/CBMinAFBVV95cUxPMThGYXpHUjdMeTRhT3FvdUFnTGYzMjlUT1pNLWJzaEZkOUZ1MHdIODA0blp2V2hFSS1oLWJDeHRNNzlBWUZwN01pcGVTZVNEN2I0eGRtTHRycm5HRFJqS21NdGZXejFmZXF6R2YyWDBiV3lMWWI2VEtvaE92dWRWekcxMGgtQXFKY095QkE1cTVMdjhGd25qZ0pKSmk?oc=5',
#   'normalized_title_1': 'bis capstone projects deliver technology solutions '
#                         'tulsa nonprofits',
#   'normalized_title_2': 'bis capstone projects deliver technology solutions '
#                         'tulsa nonprofits',
#   'pubDate_1': '2026-04-30 21:04:45',
#   'pubDate_2': 'Thu, 30 Apr 2026 21:04:45 GMT',
#   'similarity': '1.0000',
#   'source_1': 'news_utulsa',
#   'source_2': 'The University of Tulsa',
#   'title_1': 'BIS Capstone projects deliver technology solutions for Tulsa '
#              'nonprofits',
#   'title_2': 'BIS Capstone projects deliver technology solutions for Tulsa '
#              'nonprofits - The University of Tulsa'}]

# %%
write_csv(
    CONFIG['pairs_out_csv'],
    pairs,
    fieldnames=[
        'title_1', 'title_2', 'normalized_title_1', 'normalized_title_2', 'similarity',
        'source_1', 'source_2', 'link_1', 'link_2', 'pubDate_1', 'pubDate_2'
    ],
)
write_json(CONFIG['pairs_out_json'], pairs)

print('\n=== PIPELINE OZETI ===')
print(f"Ham kayit sayisi         : {len(raw_records)}")
print(f"Normalize kayit sayisi   : {len(normalized_records)}")
print(f"Esik degeri              : {CONFIG['threshold']:.2f}")
print(f"Duplicate cift sayisi    : {len(pairs)}")
print(f"Normalize CSV            : {CONFIG['normalized_out_csv']}")
print(f"Normalize JSON           : {CONFIG['normalized_out_json']}")
print(f"Duplicate CSV            : {CONFIG['pairs_out_csv']}")
print(f"Duplicate JSON           : {CONFIG['pairs_out_json']}")
# Out:
# [write_csv] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv
# [write_csv] Satir sayisi: 161
# [write_csv] Tamamlandi
# [write_json] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json
# [write_json] Kayit sayisi: 161
# [write_json] Tamamlandi
#
# === PIPELINE OZETI ===
# Ham kayit sayisi         : 2805
# Normalize kayit sayisi   : 2798
# Esik degeri              : 0.85
# Duplicate cift sayisi    : 161
# Normalize CSV            : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# Normalize JSON           : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json
# Duplicate CSV            : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv
# Duplicate JSON           : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json

# %%
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np

print('[11/11] Zipf kutuphaneleri yuklendi.')
# Out:
# [11/11] Zipf kutuphaneleri yuklendi.

# %%
# Normalize edilmis basliklardan tek bir token listesi olustur.
all_tokens = []
for rec in normalized_records:
    all_tokens.extend((rec.get('normalized_title') or '').split())

if not all_tokens:
    raise ValueError('Zipf analizi icin token bulunamadi.')

# Kelime frekanslarini hesapla.
word_freq = Counter(all_tokens)
sorted_items = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
sorted_freqs = [freq for _, freq in sorted_items]
ranks = np.arange(1, len(sorted_freqs) + 1)

print(f'Toplam token sayisi: {len(all_tokens)}')
print(f'Tekil kelime sayisi: {len(word_freq)}')
print('En sık 15 kelime:')
for word, freq in sorted_items[:15]:
    print(f'  {word}: {freq}')

# Rank-Frequency tablosunun ilk satirlarini goster.
zipf_preview = [
    {'rank': i + 1, 'word': sorted_items[i][0], 'frequency': sorted_items[i][1]}
    for i in range(min(20, len(sorted_items)))
]
pprint(zipf_preview)

# Zipf log-log grafigi.
plt.figure(figsize=(8, 5))
plt.loglog(ranks, sorted_freqs, marker='o', linestyle='none', markersize=3, alpha=0.65)
plt.xlabel('Kelime Sirasi (log)')
plt.ylabel('Frekans (log)')
plt.title('Headlines Verisi Icin Zipf Yasasi')
plt.grid(True, which='both', linestyle='--', alpha=0.3)
plt.show()

# Basit uyum ozeti (ilk N rank icin log-log lineer fit).
fit_n = min(300, len(sorted_freqs))
log_ranks = np.log(ranks[:fit_n])
log_freqs = np.log(np.array(sorted_freqs[:fit_n], dtype=float))
slope, intercept = np.polyfit(log_ranks, log_freqs, 1)
print(f'Log-log egim (ilk {fit_n} rank): {slope:.3f}')
print('Not: Eğim -1 civarına yaklaştıkça klasik Zipf davranışı daha belirgin olur.')
# Out:
# Toplam token sayisi: 21428
# Tekil kelime sayisi: 6619
# En sık 15 kelime:
#   technology: 153
#   stock: 147
#   market: 131
#   global: 118
#   innovation: 111
#   energy: 107
#   quantum: 107
#   space: 104
#   computing: 103
#   cloud: 95
#   business: 94
#   iran: 93
#   world: 88
#   climate: 87
#   software: 87
# [{'frequency': 153, 'rank': 1, 'word': 'technology'},
#  {'frequency': 147, 'rank': 2, 'word': 'stock'},
#  {'frequency': 131, 'rank': 3, 'word': 'market'},
#  {'frequency': 118, 'rank': 4, 'word': 'global'},
#  {'frequency': 111, 'rank': 5, 'word': 'innovation'},
#  {'frequency': 107, 'rank': 6, 'word': 'energy'},
#  {'frequency': 107, 'rank': 7, 'word': 'quantum'},
#  {'frequency': 104, 'rank': 8, 'word': 'space'},
#  {'frequency': 103, 'rank': 9, 'word': 'computing'},
#  {'frequency': 95, 'rank': 10, 'word': 'cloud'},
#  {'frequency': 94, 'rank': 11, 'word': 'business'},
#  {'frequency': 93, 'rank': 12, 'word': 'iran'},
#  {'frequency': 88, 'rank': 13, 'word': 'world'},
#  {'frequency': 87, 'rank': 14, 'word': 'climate'},
#  {'frequency': 87, 'rank': 15, 'word': 'software'},
#  {'frequency': 86, 'rank': 16, 'word': 'healthcare'},
#  {'frequency': 81, 'rank': 17, 'word': 'learning'},
#  {'frequency': 78, 'rank': 18, 'word': 'change'},
#  {'frequency': 78, 'rank': 19, 'word': 'fintech'},
#  {'frequency': 77, 'rank': 20, 'word': 'data'}]
# Log-log egim (ilk 300 rank): -0.628
# Not: Eğim -1 civarına yaklaştıkça klasik Zipf davranışı daha belirgin olur.

# %% [markdown]
# ## 4. Ham Veri vs Temizlenmiş Veri vs Çıktı Veri (Açıklamalı)
#
# Bu bölümde pipeline sonucunu anlaşılır şekilde görmek için üç veri katmanı birlikte gösterilir:
#
# - **Ham veri (`headlines_all.json`)**: Botlardan/API kaynaklarından gelen orijinal kayıtlar.
# - **Temizlenmiş veri (`headlines_normalized_all.csv/.json`)**: Ön işleme uygulanmış, modele uygun hale getirilmiş kayıtlar (`normalized_title` dahil).
# - **Çıktı veri (`duplicate_pairs_all.csv/.json`)**: Benzerlik eşik değeri ile tespit edilen potansiyel duplicate çiftler.
#
# Aşağıdaki hücre, her katman için:
# 1. Dosya yolu, kayıt sayısı ve boyut bilgisini,
# 2. İlk birkaç örnek kaydı,
# 3. Ham > temiz dönüşümünü (aynı kaydın `title` ve `normalized_title` karşılaştırması) üretir.

# %%
# json/csv/os kutuphaneleri: dosya okuma, satir analizi ve boyut bilgisi icin kullaniliyor.
import json
import csv
import os
from pprint import pprint


def read_json_records(path):
    with path.open('r', encoding='utf-8') as f:
        data = json.load(f)
    return data if isinstance(data, list) else []


def read_csv_records(path):
    with path.open('r', encoding='utf-8', newline='') as f:
        return list(csv.DictReader(f))


def mb(path):
    return round(path.stat().st_size / (1024 * 1024), 3)


raw_path = CONFIG['input_json']
clean_json_path = CONFIG['normalized_out_json']
clean_csv_path = CONFIG['normalized_out_csv']
pairs_json_path = CONFIG['pairs_out_json']
pairs_csv_path = CONFIG['pairs_out_csv']

raw_records = read_json_records(raw_path)
clean_json_records = read_json_records(clean_json_path)
clean_csv_records = read_csv_records(clean_csv_path)
pairs_json_records = read_json_records(pairs_json_path)
pairs_csv_records = read_csv_records(pairs_csv_path)

print('=== DOSYA OZETLERI ===')
print(f'Ham veri JSON      : {raw_path} | kayit={len(raw_records)} | boyut={mb(raw_path)} MB')
print(f'Temiz veri JSON    : {clean_json_path} | kayit={len(clean_json_records)} | boyut={mb(clean_json_path)} MB')
print(f'Temiz veri CSV     : {clean_csv_path} | kayit={len(clean_csv_records)} | boyut={mb(clean_csv_path)} MB')
print(f'Cikti pair JSON    : {pairs_json_path} | kayit={len(pairs_json_records)} | boyut={mb(pairs_json_path)} MB')
print(f'Cikti pair CSV     : {pairs_csv_path} | kayit={len(pairs_csv_records)} | boyut={mb(pairs_csv_path)} MB')


print('\n' + '=' * 90)
print('1) HAM VERI ORNEKLERI (ilk 3 kayit)')
print('=' * 90)
for i, row in enumerate(raw_records[:3], start=1):
    print(f'\n[Ham Kayit {i}]')
    pprint({
        'title': row.get('title'),
        'source': row.get('source'),
        'link': row.get('link'),
        'pubDate': row.get('pubDate')
    })


print('\n' + '=' * 90)
print('2) TEMIZLENMIS VERI ORNEKLERI (ilk 3 kayit)')
print('=' * 90)
for i, row in enumerate(clean_csv_records[:3], start=1):
    print(f'\n[Temiz Kayit {i}]')
    pprint({
        'title': row.get('title'),
        'normalized_title': row.get('normalized_title'),
        'source': row.get('source'),
        'link': row.get('link'),
        'pubDate': row.get('pubDate')
    })


print('\n' + '=' * 90)
print('3) CIKTI VERISI ORNEKLERI (duplicate pair ilk 3 kayit)')
print('=' * 90)
for i, row in enumerate(pairs_csv_records[:3], start=1):
    print(f'\n[Cikti Pair {i}]')
    pprint({
        'title_1': row.get('title_1'),
        'title_2': row.get('title_2'),
        'similarity': row.get('similarity'),
        'source_1': row.get('source_1'),
        'source_2': row.get('source_2')
    })


print('\n' + '=' * 90)
print('4) HAM -> TEMIZ DONUSUM ORNEGI (ilk 5 kayit)')
print('=' * 90)
for i, row in enumerate(clean_csv_records[:5], start=1):
    raw_title = row.get('title', '')
    normalized_title = row.get('normalized_title', '')
    print(f'\n[Donusum {i}]')
    print('Ham Baslik       :', raw_title)
    print('Temiz Baslik     :', normalized_title)

print('\nAciklama: Ham veri kaynaklardan geldigi haliyle saklanir. Temiz veri, model egitimi icin normalize edilmis metni icerir. Cikti veri ise benzerlik esigine gore duplicate olarak isaretlenen kayit ciftlerini tutar.')
# Out:
# === DOSYA OZETLERI ===
# Ham veri JSON      : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\all\headlines_all.json | kayit=2805 | boyut=1.449 MB
# Temiz veri JSON    : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json | kayit=2798 | boyut=1.531 MB
# Temiz veri CSV     : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv | kayit=2798 | boyut=1.252 MB
# Cikti pair JSON    : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json | kayit=161 | boyut=0.199 MB
# Cikti pair CSV     : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv | kayit=161 | boyut=0.162 MB
#
# ==========================================================================================
# 1) HAM VERI ORNEKLERI (ilk 3 kayit)
# ==========================================================================================
#
# [Ham Kayit 1]
# {'link': 'https://www.marketwatch.com/bulletins/redirect/go?g=dab30966-8cf2-4a64-ba38-bbf711571f2f&mod=mw_rss_bulletins',
#  'pubDate': '2026-04-30 21:06:53',
#  'source': 'marketwatch',
#  'title': 'U.S. stocks clock best month since 2020 as Wall Street shakes off '
#           'Iran oil shock'}
#
# [Ham Kayit 2]
# {'link': 'https://us.headtopics.com/news/faa-chief-predicts-fewer-air-traffic-control-delays-this-82875820',
#  'pubDate': '2026-04-30 21:06:40',
#  'source': 'headtopics',
#  'title': 'FAA chief predicts fewer air traffic control delays this summer'}
#
# [Ham Kayit 3]
# {'link': 'https://us.headtopics.com/news/stephen-king-s-2-new-shows-in-2026-will-tell-the-same-dark-82875852',
#  'pubDate': '2026-04-30 21:06:40',
#  'source': 'headtopics',
#  'title': 'Stephen King’s 2 New Shows In 2026 Will Tell The Same Dark Story'}
#
# ==========================================================================================
# 2) TEMIZLENMIS VERI ORNEKLERI (ilk 3 kayit)
# ==========================================================================================
#
# [Temiz Kayit 1]
# {'link': 'https://www.marketwatch.com/bulletins/redirect/go?g=dab30966-8cf2-4a64-ba38-bbf711571f2f&mod=mw_rss_bulletins',
#  'normalized_title': 'stocks clock best month since wall street shakes iran '
#                      'oil shock',
#  'pubDate': '2026-04-30 21:06:53',
#  'source': 'marketwatch',
#  'title': 'U.S. stocks clock best month since 2020 as Wall Street shakes off '
#           'Iran oil shock'}
#
# [Temiz Kayit 2]
# {'link': 'https://us.headtopics.com/news/faa-chief-predicts-fewer-air-traffic-control-delays-this-82875820',
#  'normalized_title': 'faa chief predicts fewer air traffic control delays '
#                      'summer',
#  'pubDate': '2026-04-30 21:06:40',
#  'source': 'headtopics',
#  'title': 'FAA chief predicts fewer air traffic control delays this summer'}
#
# [Temiz Kayit 3]
# {'link': 'https://us.headtopics.com/news/stephen-king-s-2-new-shows-in-2026-will-tell-the-same-dark-82875852',
#  'normalized_title': 'stephen king shows tell dark story',
#  'pubDate': '2026-04-30 21:06:40',
#  'source': 'headtopics',
#  'title': 'Stephen King’s 2 New Shows In 2026 Will Tell The Same Dark Story'}
#
# ==========================================================================================
# 3) CIKTI VERISI ORNEKLERI (duplicate pair ilk 3 kayit)
# ==========================================================================================
#
# [Cikti Pair 1]
# {'similarity': '0.9181',
#  'source_1': 'mongabay',
#  'source_2': 'news - Mongabay',
#  'title_1': 'In Guatemala, new AI technology will be ‘listening’ for illegal '
#             'deforestation',
#  'title_2': 'In Guatemala, new AI technology will be ‘listening’ for illegal '
#             'deforestation - news - Mongabay'}
#
# [Cikti Pair 2]
# {'similarity': '1.0000',
#  'source_1': 'benzinga',
#  'source_2': 'globenewswire',
#  'title_1': 'Fairfax India Holdings Corporation: First Quarter Financial '
#             'Results',
#  'title_2': 'Fairfax India Holdings Corporation: First Quarter Financial '
#             'Results'}
#
# [Cikti Pair 3]
# {'similarity': '1.0000',
#  'source_1': 'news_utulsa',
#  'source_2': 'The University of Tulsa',
#  'title_1': 'BIS Capstone projects deliver technology solutions for Tulsa '
#             'nonprofits',
#  'title_2': 'BIS Capstone projects deliver technology solutions for Tulsa '
#             'nonprofits - The University of Tulsa'}
#
# ==========================================================================================
# 4) HAM -> TEMIZ DONUSUM ORNEGI (ilk 5 kayit)
# ==========================================================================================
#
# [Donusum 1]
# Ham Baslik       : U.S. stocks clock best month since 2020 as Wall Street shakes off Iran oil shock
# Temiz Baslik     : stocks clock best month since wall street shakes iran oil shock
#
# [Donusum 2]
# Ham Baslik       : FAA chief predicts fewer air traffic control delays this summer
# Temiz Baslik     : faa chief predicts fewer air traffic control delays summer
#
# [Donusum 3]
# Ham Baslik       : Stephen King’s 2 New Shows In 2026 Will Tell The Same Dark Story
# Temiz Baslik     : stephen king shows tell dark story
#
# [Donusum 4]
# Ham Baslik       : Tennessee man uses lasers to make the world’s thinnest car
# Temiz Baslik     : tennessee man uses lasers make world thinnest car
#
# [Donusum 5]
# Ham Baslik       : Chicago police officer John Bartholomew's accused killer ordered held until murder trial
# Temiz Baslik     : chicago police officer john bartholomew accused killer ordered held murder trial
#
# Aciklama: Ham veri kaynaklardan geldigi haliyle saklanir. Temiz veri, model egitimi icin normalize edilmis metni icerir. Cikti veri ise benzerlik esigine gore duplicate olarak isaretlenen kayit ciftlerini tutar.

# %% [markdown]
# # Word2Vec ile Metin Benzerliği ve Değerlendirme
#
# **Öğrenciler:** Mustafa Mete / 2202131015, Emine Avcu / 2202131006
#
# Bu bölüm önceki bölüm çıktıları (`lemmatized.csv`, `stemmed.csv`) üzerinde çalışır.
#
# ## Akış
# 1. Önceki bölüm temiz veri setlerini üret ve kaydet
# 2. 16 Word2Vec modeli eğit (8 parametre × 2 veri seti)
# 3. Giriş metnine en benzer 5 başlığı her model için bul
# 4. Cosine, anlamsal ve Jaccard değerlendirmesi yap

# %% [markdown]
# ## lemmatized.csv ve stemmed.csv
#
# Ham başlıklar üzerinde Önceki Bölüm ön işleme adımları (temizlik, lowercasing, tokenization, stopword, lemmatization, stemming) uygulanır ve model eğitimi için iki ayrı CSV üretilir.

# %%
# Ödev-2 yolları ve Ödev-1 CSV üretimi
ODEV2_CONFIG = {
    'lemmatized_csv': CONFIG['input_json'].parent.parent / 'processed' / 'lemmatized.csv',
    'stemmed_csv': CONFIG['input_json'].parent.parent / 'processed' / 'stemmed.csv',
    'models_dir': CONFIG['input_json'].parent.parent.parent / 'models',
    'results_dir': CONFIG['input_json'].parent.parent / 'results' / 'odev2',
    'top_k': 5,
    'w2v_epochs': 10,
    'w2v_min_count': 1,
}

ODEV2_CONFIG['models_dir'].mkdir(parents=True, exist_ok=True)
ODEV2_CONFIG['results_dir'].mkdir(parents=True, exist_ok=True)

lemmatized_rows = []
stemmed_rows = []

for item in raw_records:
    title = (item.get('title') or '').strip()
    if not title:
        continue

    cleaned = clean_general_content(title).lower()
    _, tokenized = tokenize_with_sentences(cleaned)
    no_stop = remove_stopwords(tokenized)
    lemmatized_sents = lemmatize_tokens(no_stop)
    stemmed_sents = stem_tokens(lemmatized_sents)

    lem_tokens = [tok for sent in lemmatized_sents for tok in sent]
    stem_tokens_list = [tok for sent in stemmed_sents for tok in sent]
    if not lem_tokens:
        continue

    base = {
        'title': title,
        'source': item.get('source') or '',
        'link': item.get('link') or '',
        'pubDate': item.get('pubDate') or '',
    }
    lemmatized_rows.append({**base, 'content': ' '.join(lem_tokens)})
    stemmed_rows.append({**base, 'content': ' '.join(stem_tokens_list)})

fieldnames = ['title', 'content', 'source', 'link', 'pubDate']
write_csv(ODEV2_CONFIG['lemmatized_csv'], lemmatized_rows, fieldnames=fieldnames)
write_csv(ODEV2_CONFIG['stemmed_csv'], stemmed_rows, fieldnames=fieldnames)

print(f'lemmatized.csv kaydedildi: {ODEV2_CONFIG["lemmatized_csv"]} | kayit={len(lemmatized_rows)}')
print(f'stemmed.csv kaydedildi   : {ODEV2_CONFIG["stemmed_csv"]} | kayit={len(stemmed_rows)}')
print('Ornek lemmatized content :', lemmatized_rows[0]['content'][:120])
print('Ornek stemmed content    :', stemmed_rows[0]['content'][:120])
# Out:
# [write_csv] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\lemmatized.csv
# [write_csv] Satir sayisi: 2805
# [write_csv] Tamamlandi
# [write_csv] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\stemmed.csv
# [write_csv] Satir sayisi: 2805
# [write_csv] Tamamlandi
# lemmatized.csv kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\lemmatized.csv | kayit=2805
# stemmed.csv kaydedildi   : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\stemmed.csv | kayit=2805
# Ornek lemmatized content : u.s. stock clock best month since wall street shake iran oil shock
# Ornek stemmed content    : u.s. stock clock best month sinc wall street shake iran oil shock

# %% [markdown]
# ## Word2Vec Vektörleştirme
#
# Gensim ile 8 parametre seti × 2 veri seti = **16 model** eğitilir.
#
# Parametreler: CBOW / Skip-gram, window = 2 veya 4, vector_size = 100 veya 300.

# %%
from gensim.models import Word2Vec

W2V_PARAMETERS = [
    {'model_type': 'cbow', 'window': 2, 'vector_size': 100},
    {'model_type': 'skipgram', 'window': 2, 'vector_size': 100},
    {'model_type': 'cbow', 'window': 4, 'vector_size': 100},
    {'model_type': 'skipgram', 'window': 4, 'vector_size': 100},
    {'model_type': 'cbow', 'window': 2, 'vector_size': 300},
    {'model_type': 'skipgram', 'window': 2, 'vector_size': 300},
    {'model_type': 'cbow', 'window': 4, 'vector_size': 300},
    {'model_type': 'skipgram', 'window': 4, 'vector_size': 300},
]

DATASETS = {
    'lemmatized': lemmatized_rows,
    'stemmed': stemmed_rows,
}


def build_model_name(dataset_name: str, params: dict) -> str:
    return (
        f"word2vec_{dataset_name}_{params['model_type']}"
        f"_win{params['window']}_dim{params['vector_size']}.model"
    )


def rows_to_sentences(rows):
    return [row['content'].split() for row in rows if row.get('content')]


trained_models = {}
nearest_words_report = {}

for dataset_name, rows in DATASETS.items():
    sentences = rows_to_sentences(rows)
    for params in W2V_PARAMETERS:
        model_name = build_model_name(dataset_name, params)
        model_path = ODEV2_CONFIG['models_dir'] / model_name
        sg = 0 if params['model_type'] == 'cbow' else 1

        model = Word2Vec(
            sentences=sentences,
            vector_size=params['vector_size'],
            window=params['window'],
            min_count=ODEV2_CONFIG['w2v_min_count'],
            workers=4,
            sg=sg,
            epochs=ODEV2_CONFIG['w2v_epochs'],
        )
        model.save(str(model_path))
        trained_models[model_name] = model

        # Rapor için örnek kelime: veri setinde en sık geçen anlamlı kelime
        sample_word = 'technology' if any('technology' in s for s in sentences) else sentences[0][0]
        if sample_word in model.wv:
            similar = model.wv.most_similar(sample_word, topn=5)
            nearest_words_report[model_name] = {
                'sample_word': sample_word,
                'nearest_words': [(w, round(float(score), 4)) for w, score in similar],
            }
        else:
            nearest_words_report[model_name] = {
                'sample_word': sample_word,
                'nearest_words': [],
            }

        print(f'Egitildi: {model_name} | vocab={len(model.wv)}')

print(f'\nToplam egitilen model: {len(trained_models)}')
print('\n=== ORNEK: technology kelimesine en yakin 5 kelime (ilk 3 model) ===')
for i, (name, info) in enumerate(nearest_words_report.items()):
    if i >= 3:
        break
    print(f'\n{name}')
    print(f"  Ornek kelime: {info['sample_word']}")
    for word, score in info['nearest_words']:
        print(f'    {word}: {score}')
# Out:
# Egitildi: word2vec_lemmatized_cbow_win2_dim100.model | vocab=6911
# Egitildi: word2vec_lemmatized_skipgram_win2_dim100.model | vocab=6911
# Egitildi: word2vec_lemmatized_cbow_win4_dim100.model | vocab=6911
# Egitildi: word2vec_lemmatized_skipgram_win4_dim100.model | vocab=6911
# Egitildi: word2vec_lemmatized_cbow_win2_dim300.model | vocab=6911
# Egitildi: word2vec_lemmatized_skipgram_win2_dim300.model | vocab=6911
# Egitildi: word2vec_lemmatized_cbow_win4_dim300.model | vocab=6911
# Egitildi: word2vec_lemmatized_skipgram_win4_dim300.model | vocab=6911
# Egitildi: word2vec_stemmed_cbow_win2_dim100.model | vocab=5969
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Egitildi: word2vec_stemmed_skipgram_win2_dim100.model | vocab=5969
# Egitildi: word2vec_stemmed_cbow_win4_dim100.model | vocab=5969
# Egitildi: word2vec_stemmed_skipgram_win4_dim100.model | vocab=5969
# Egitildi: word2vec_stemmed_cbow_win2_dim300.model | vocab=5969
# Egitildi: word2vec_stemmed_skipgram_win2_dim300.model | vocab=5969
# Egitildi: word2vec_stemmed_cbow_win4_dim300.model | vocab=5969
# Egitildi: word2vec_stemmed_skipgram_win4_dim300.model | vocab=5969
#
# Toplam egitilen model: 16
#
# === ORNEK: technology kelimesine en yakin 5 kelime (ilk 3 model) ===
#
# word2vec_lemmatized_cbow_win2_dim100.model
#   Ornek kelime: technology
#     innovation: 0.9984
#     robotics: 0.9983
#     news: 0.9983
#     tech: 0.9983
#     startup: 0.9982
#
# word2vec_lemmatized_skipgram_win2_dim100.model
#   Ornek kelime: technology
#     india: 0.9952
#     defense: 0.995
#     county: 0.995
#     clinic: 0.995
#     force: 0.9949
#
# word2vec_lemmatized_cbow_win4_dim100.model
#   Ornek kelime: technology
#     innovation: 0.9997
#     robotics: 0.9997
#     healthcare: 0.9997
#     news: 0.9997
#     cybersecurity: 0.9996

# %% [markdown]
# ## Metin Benzerliklerinin Hesaplanması
#
# - Giriş metni veri setinden seçilir (yapay zeka / teknoloji temalı haber başlığı)
# - Her model için tüm başlıklarla cosine benzerliği hesaplanır
# - Ortalama kelime vektörü yöntemi kullanılır; modelde olmayan kelimeler atlanır
# - Boş vektör durumunda sıfır vektör atanır

# %%
from sklearn.metrics.pairwise import cosine_similarity as sk_cosine_similarity


def sentence_vector(model, tokens):
    """Modelde bulunan kelimelerin vektör ortalamasını alır."""
    vectors = [model.wv[t] for t in tokens if t in model.wv]
    if not vectors:
        return np.zeros(model.vector_size, dtype=float)
    return np.mean(vectors, axis=0)


def find_query_index(rows, keywords):
    for idx, row in enumerate(rows):
        title_lower = row['title'].lower()
        if all(kw in title_lower for kw in keywords):
            return idx
    return 0


# Veri setinden anlamlı bir giriş metni seç (yapay zeka temalı başlık)
QUERY_KEYWORDS = ['artificial', 'intelligence']
query_idx_lem = find_query_index(lemmatized_rows, QUERY_KEYWORDS)
query_idx_stem = find_query_index(stemmed_rows, QUERY_KEYWORDS)

QUERY_BY_DATASET = {
    'lemmatized': {
        'index': query_idx_lem,
        'title': lemmatized_rows[query_idx_lem]['title'],
        'tokens': lemmatized_rows[query_idx_lem]['content'].split(),
        'rows': lemmatized_rows,
    },
    'stemmed': {
        'index': query_idx_stem,
        'title': stemmed_rows[query_idx_stem]['title'],
        'tokens': stemmed_rows[query_idx_stem]['content'].split(),
        'rows': stemmed_rows,
    },
}

print('=== GIRIS METNI  ===')
for dataset_name, info in QUERY_BY_DATASET.items():
    print(f'\n[{dataset_name}]')
    print('Baslik :', info['title'])
    print('Tokenlar:', ' '.join(info['tokens']))

similarity_results = {}
top_k = ODEV2_CONFIG['top_k']

for model_name, model in trained_models.items():
    dataset_name = 'lemmatized' if model_name.startswith('word2vec_lemmatized_') else 'stemmed'
    ds = QUERY_BY_DATASET[dataset_name]
    query_vec = sentence_vector(model, ds['tokens'])

    scores = []
    for idx, row in enumerate(ds['rows']):
        if idx == ds['index']:
            continue
        doc_vec = sentence_vector(model, row['content'].split())
        score = float(sk_cosine_similarity(query_vec.reshape(1, -1), doc_vec.reshape(1, -1))[0][0])
        scores.append((idx, score))

    scores.sort(key=lambda x: x[1], reverse=True)
    top_matches = []
    for rank, (idx, score) in enumerate(scores[:top_k], start=1):
        row = ds['rows'][idx]
        top_matches.append({
            'rank': rank,
            'doc_id': idx,
            'title': row['title'],
            'content': row['content'],
            'source': row['source'],
            'similarity': round(score, 4),
        })

    similarity_results[model_name] = {
        'dataset': dataset_name,
        'query_title': ds['title'],
        'query_tokens': ds['tokens'],
        'top_matches': top_matches,
        'cosine_scores': [m['similarity'] for m in top_matches],
        'cosine_avg': round(float(np.mean([m['similarity'] for m in top_matches])), 4) if top_matches else 0.0,
    }

    print(f"\n{model_name}")
    print(f"  Cosine ortalama: {similarity_results[model_name]['cosine_avg']}")
    for m in top_matches:
        print(f"  {m['rank']}. [{m['similarity']}] {m['title']}")

# JSON olarak kaydet
results_json_path = ODEV2_CONFIG['results_dir'] / 'similarity_results_all.json'
write_json(results_json_path, similarity_results)
print(f'\nSonuclar kaydedildi: {results_json_path}')
# Out:
# === GIRIS METNI  ===
#
# [lemmatized]
# Baslik : Reddit's CEO calls his company 'the fuel' for artificial intelligence - CNBC
# Tokenlar: reddit ceo call company fuel artificial intelligence cnbc
#
# [stemmed]
# Baslik : Reddit's CEO calls his company 'the fuel' for artificial intelligence - CNBC
# Tokenlar: reddit ceo call compani fuel artifici intellig cnbc
#
# word2vec_lemmatized_cbow_win2_dim100.model
#   Cosine ortalama: 0.9993
#   1. [0.9994] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   2. [0.9993] Peer review in the time of artificial intelligence - Nature
#   3. [0.9993] Bayraktar maps Türkiye’s energy future from Akkuyu to artificial intelligence - AzerNews
#   4. [0.9993] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   5. [0.9992] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#
# word2vec_lemmatized_skipgram_win2_dim100.model
#   Cosine ortalama: 0.999
#   1. [0.9995] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   2. [0.9992] Leveraging Artificial Intelligence to Prevent Homelessness in Los Angeles County - America's Essential Hospitals
#   3. [0.999] Forbes 2026 AI 50 List | Top Artificial Intelligence Companies - Forbes
#   4. [0.9988] Senator Banks raises concerns over Chinese espionage targeting U.S. artificial intelligence sector - WBIW
#   5. [0.9987] IN AI: Braun unveils artificial intelligence business portal - Indiana Capital Chronicle
#
# word2vec_lemmatized_cbow_win4_dim100.model
#   Cosine ortalama: 0.9999
#   1. [0.9999] Bayraktar maps Türkiye’s energy future from Akkuyu to artificial intelligence - AzerNews
#   2. [0.9999] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   3. [0.9999] Peer review in the time of artificial intelligence - Nature
#   4. [0.9998] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   5. [0.9998] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#
# word2vec_lemmatized_skipgram_win4_dim100.model
#   Cosine ortalama: 0.9979
#   1. [0.9991] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   2. [0.9979] As artificial intelligence shows off diagnostic chops, scientists reckon with the way forward - statnews.com
#   3. [0.9976] Leveraging Artificial Intelligence to Prevent Homelessness in Los Angeles County - America's Essential Hospitals
#   4. [0.9975] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   5. [0.9972] Taxing Artificial Intelligence Would Be a Big Mistake - Bloomberg.com
#
# word2vec_lemmatized_cbow_win2_dim300.model
#   Cosine ortalama: 0.9995
#   1. [0.9996] FAQ on AI in OOH advertising: How artificial intelligence is reshaping the channel in 2026 - eMarketer
#   2. [0.9995] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   3. [0.9995] Peer review in the time of artificial intelligence - Nature
#   4. [0.9995] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   5. [0.9995] Explainable AI needs formalization - npj Artificial Intelligence - Nature
#
# word2vec_lemmatized_skipgram_win2_dim300.model
#   Cosine ortalama: 0.9996
#   1. [0.9997] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   2. [0.9997] Forbes 2026 AI 50 List | Top Artificial Intelligence Companies - Forbes
#   3. [0.9996] IN AI: Braun unveils artificial intelligence business portal - Indiana Capital Chronicle
#   4. [0.9995] Leveraging Artificial Intelligence to Prevent Homelessness in Los Angeles County - America's Essential Hospitals
#   5. [0.9994] Multi-agent artificial intelligence designs novel catalysts for ultrafast water purification - Nature
#
# word2vec_lemmatized_cbow_win4_dim300.model
#   Cosine ortalama: 0.9999
#   1. [0.9999] Explainable AI needs formalization - npj Artificial Intelligence - Nature
#   2. [0.9999] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   3. [0.9999] Peer review in the time of artificial intelligence - Nature
#   4. [0.9999] FAQ on AI in OOH advertising: How artificial intelligence is reshaping the channel in 2026 - eMarketer
#   5. [0.9999] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#
# word2vec_lemmatized_skipgram_win4_dim300.model
#   Cosine ortalama: 0.999
#   1. [0.9994] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   2. [0.9994] Leveraging Artificial Intelligence to Prevent Homelessness in Los Angeles County - America's Essential Hospitals
#   3. [0.9988] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   4. [0.9988] As artificial intelligence shows off diagnostic chops, scientists reckon with the way forward - statnews.com
#   5. [0.9985] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#
# word2vec_stemmed_cbow_win2_dim100.model
#   Cosine ortalama: 0.9996
#   1. [0.9996] Peer review in the time of artificial intelligence - Nature
#   2. [0.9996] FAQ on AI in OOH advertising: How artificial intelligence is reshaping the channel in 2026 - eMarketer
#   3. [0.9996] Explainable AI needs formalization - npj Artificial Intelligence - Nature
#   4. [0.9996] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   5. [0.9996] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#
# word2vec_stemmed_skipgram_win2_dim100.model
#   Cosine ortalama: 0.999
#   1. [0.9995] Leveraging Artificial Intelligence to Prevent Homelessness in Los Angeles County - America's Essential Hospitals
#   2. [0.999] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   3. [0.9989] Forbes 2026 AI 50 List | Top Artificial Intelligence Companies - Forbes
#   4. [0.9989] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   5. [0.9987] As artificial intelligence shows off diagnostic chops, scientists reckon with the way forward - statnews.com
#
# word2vec_stemmed_cbow_win4_dim100.model
#   Cosine ortalama: 0.9999
#   1. [0.9999] Forbes 2026 AI 50 List | Top Artificial Intelligence Companies - Forbes
#   2. [0.9999] Peer review in the time of artificial intelligence - Nature
#   3. [0.9999] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   4. [0.9999] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   5. [0.9998] Bayraktar maps Türkiye’s energy future from Akkuyu to artificial intelligence - AzerNews
#
# word2vec_stemmed_skipgram_win4_dim100.model
#   Cosine ortalama: 0.9955
#   1. [0.9961] Taxing Artificial Intelligence Would Be a Big Mistake - Bloomberg.com
#   2. [0.9956] Prediction: This Under-the-Radar Artificial Intelligence (AI) Stock Could Be a Multibagger by the End of 2027 - The Globe and Mail
#   3. [0.9955] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   4. [0.9951] Prediction: This under-the-radar artificial intelligence (AI) stock could be a multibagger by the end of 2027 - MSN
#   5. [0.995] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#
# word2vec_stemmed_cbow_win2_dim300.model
#   Cosine ortalama: 0.9998
#   1. [0.9998] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   2. [0.9998] Bayraktar maps Türkiye’s energy future from Akkuyu to artificial intelligence - AzerNews
#   3. [0.9998] Explainable AI needs formalization - npj Artificial Intelligence - Nature
#   4. [0.9998] Peer review in the time of artificial intelligence - Nature
#   5. [0.9998] FAQ on AI in OOH advertising: How artificial intelligence is reshaping the channel in 2026 - eMarketer
#
# word2vec_stemmed_skipgram_win2_dim300.model
#   Cosine ortalama: 0.9994
#   1. [0.9998] Leveraging Artificial Intelligence to Prevent Homelessness in Los Angeles County - America's Essential Hospitals
#   2. [0.9996] Forbes 2026 AI 50 List | Top Artificial Intelligence Companies - Forbes
#   3. [0.9993] IN AI: Braun unveils artificial intelligence business portal - Indiana Capital Chronicle
#   4. [0.9992] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   5. [0.9992] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#
# word2vec_stemmed_cbow_win4_dim300.model
#   Cosine ortalama: 0.9999
#   1. [1.0] Artificial Intelligence in Education is Focus of IgniteND Conference - News Dakota
#   2. [1.0] Forbes 2026 AI 50 List | Top Artificial Intelligence Companies - Forbes
#   3. [0.9999] Peer review in the time of artificial intelligence - Nature
#   4. [0.9999] Explainable AI needs formalization - npj Artificial Intelligence - Nature
#   5. [0.9999] Bayraktar maps Türkiye’s energy future from Akkuyu to artificial intelligence - AzerNews
#
# word2vec_stemmed_skipgram_win4_dim300.model
#   Cosine ortalama: 0.9978
#   1. [0.9982] Artificial intelligence is not to blame in Tumbler Ridge shooting, Carney minister says - Toronto Star
#   2. [0.998] Artificial intelligence powers Egypt’s USD 27bn city project - Computer Weekly
#   3. [0.9977] Prediction: This Under-the-Radar Artificial Intelligence (AI) Stock Could Be a Multibagger by the End of 2027 - The Globe and Mail
#   4. [0.9976] Taxing Artificial Intelligence Would Be a Big Mistake - Bloomberg.com
#   5. [0.9975] Transformational Utah Investment in Artificial Intelligence and Computing to Advance Health and Discovery | Newswise - Newswise
# [write_json] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\odev2\similarity_results_all.json
# [write_json] Kayit sayisi: N/A
# [write_json] Tamamlandi
#
# Sonuclar kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\odev2\similarity_results_all.json

# %% [markdown]
# ## Değerlendirme ve Karşılaştırma
#
# 1. **Cosine Değerlendirme (Objective)** – her modelin top-5 cosine skorları ve ortalaması
# 2. **Anlamsal Değerlendirme (Subjective)**
# 3. **Sıralama Tutarlılığı (Jaccard)** – 16×16 matris ve heatmap

# %%
import pandas as pd
import seaborn as sns

# (1) Cosine Değerlendirme Tablosu
cosine_rows = []
for model_name, result in similarity_results.items():
    scores = result['cosine_scores']
    cosine_rows.append({
        'model': model_name,
        'score_1': scores[0] if len(scores) > 0 else None,
        'score_2': scores[1] if len(scores) > 1 else None,
        'score_3': scores[2] if len(scores) > 2 else None,
        'score_4': scores[3] if len(scores) > 3 else None,
        'score_5': scores[4] if len(scores) > 4 else None,
        'cosine_avg': result['cosine_avg'],
    })

cosine_df = pd.DataFrame(cosine_rows).sort_values('cosine_avg', ascending=False)
print('=== (1) COSINE DEGERLENDIRME TABLOSU ===')
display(cosine_df)

cosine_csv_path = ODEV2_CONFIG['results_dir'] / 'cosine_evaluation.csv'
cosine_df.to_csv(cosine_csv_path, index=False, encoding='utf-8')
print(f'Kaydedildi: {cosine_csv_path}')
# Out:
# === (1) COSINE DEGERLENDIRME TABLOSU ===
#                                              model  score_1  score_2  score_3  \
# 2       word2vec_lemmatized_cbow_win4_dim100.model   0.9999   0.9999   0.9999
# 6       word2vec_lemmatized_cbow_win4_dim300.model   0.9999   0.9999   0.9999
# 10         word2vec_stemmed_cbow_win4_dim100.model   0.9999   0.9999   0.9999
# 14         word2vec_stemmed_cbow_win4_dim300.model   1.0000   1.0000   0.9999
# 12         word2vec_stemmed_cbow_win2_dim300.model   0.9998   0.9998   0.9998
# 5   word2vec_lemmatized_skipgram_win2_dim300.model   0.9997   0.9997   0.9996
# 8          word2vec_stemmed_cbow_win2_dim100.model   0.9996   0.9996   0.9996
# 4       word2vec_lemmatized_cbow_win2_dim300.model   0.9996   0.9995   0.9995
# 13     word2vec_stemmed_skipgram_win2_dim300.model   0.9998   0.9996   0.9993
# 0       word2vec_lemmatized_cbow_win2_dim100.model   0.9994   0.9993   0.9993
# 1   word2vec_lemmatized_skipgram_win2_dim100.model   0.9995   0.9992   0.9990
# 7   word2vec_lemmatized_skipgram_win4_dim300.model   0.9994   0.9994   0.9988
# 9      word2vec_stemmed_skipgram_win2_dim100.model   0.9995   0.9990   0.9989
# 3   word2vec_lemmatized_skipgram_win4_dim100.model   0.9991   0.9979   0.9976
# 15     word2vec_stemmed_skipgram_win4_dim300.model   0.9982   0.9980   0.9977
# 11     word2vec_stemmed_skipgram_win4_dim100.model   0.9961   0.9956   0.9955
#
#     score_4  score_5  cosine_avg
# 2    0.9998   0.9998      0.9999
# 6    0.9999   0.9999      0.9999
# 10   0.9999   0.9998      0.9999
# 14   0.9999   0.9999      0.9999
# 12   0.9998   0.9998      0.9998
# 5    0.9995   0.9994      0.9996
# 8    0.9996   0.9996      0.9996
# 4    0.9995   0.9995      0.9995
# 13   0.9992   0.9992      0.9994
# 0    0.9993   0.9992      0.9993
# 1    0.9988   0.9987      0.9990
# 7    0.9988   0.9985      0.9990
# 9    0.9989   0.9987      0.9990
# 3    0.9975   0.9972      0.9979
# 15   0.9976   0.9975      0.9978
# 11   0.9951   0.9950      0.9955
# Kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\odev2\cosine_evaluation.csv

# %%
# (2) Anlamsal Değerlendirme – elle puanlama şablonu

semantic_rows = []
for model_name, result in similarity_results.items():
    for match in result['top_matches']:
        semantic_rows.append({
            'model': model_name,
            'rank': match['rank'],
            'query_title': result['query_title'],
            'matched_title': match['title'],
            'cosine_score': match['similarity'],
            'semantic_score_1_to_5': None,
        })

semantic_df = pd.DataFrame(semantic_rows)
semantic_template_path = ODEV2_CONFIG['results_dir'] / 'semantic_scores_template.csv'
semantic_df.to_csv(semantic_template_path, index=False, encoding='utf-8')

print('=== (2) ANLAMSAL DEGERLENDIRME SABLONU ===')
print('semantic_score_1_to_5 sutununu elle doldurup aşagıdaki sütunu çalıştıracagız sonrasında')
display(semantic_df.head(10))
print(f'\nSablon kaydedildi: {semantic_template_path}')
# Out:
# === (2) ANLAMSAL DEGERLENDIRME SABLONU ===
# semantic_score_1_to_5 sutununu elle doldurup aşagıdaki sütunu çalıştıracagız sonrasında
#                                             model  rank  \
# 0      word2vec_lemmatized_cbow_win2_dim100.model     1
# 1      word2vec_lemmatized_cbow_win2_dim100.model     2
# 2      word2vec_lemmatized_cbow_win2_dim100.model     3
# 3      word2vec_lemmatized_cbow_win2_dim100.model     4
# 4      word2vec_lemmatized_cbow_win2_dim100.model     5
# 5  word2vec_lemmatized_skipgram_win2_dim100.model     1
# 6  word2vec_lemmatized_skipgram_win2_dim100.model     2
# 7  word2vec_lemmatized_skipgram_win2_dim100.model     3
# 8  word2vec_lemmatized_skipgram_win2_dim100.model     4
# 9  word2vec_lemmatized_skipgram_win2_dim100.model     5
#
#                                          query_title  \
# 0  Reddit's CEO calls his company 'the fuel' for ...
# 1  Reddit's CEO calls his company 'the fuel' for ...
# 2  Reddit's CEO calls his company 'the fuel' for ...
# 3  Reddit's CEO calls his company 'the fuel' for ...
# 4  Reddit's CEO calls his company 'the fuel' for ...
# 5  Reddit's CEO calls his company 'the fuel' for ...
# 6  Reddit's CEO calls his company 'the fuel' for ...
# 7  Reddit's CEO calls his company 'the fuel' for ...
# 8  Reddit's CEO calls his company 'the fuel' for ...
# 9  Reddit's CEO calls his company 'the fuel' for ...
#
#                                        matched_title  cosine_score  \
# 0  Artificial Intelligence in Education is Focus ...        0.9994
# 1  Peer review in the time of artificial intellig...        0.9993
# 2  Bayraktar maps Türkiye’s energy future from Ak...        0.9993
# 3  Artificial intelligence powers Egypt’s USD 27b...        0.9993
# 4  Artificial intelligence is not to blame in Tum...        0.9992
# 5  Artificial intelligence powers Egypt’s USD 27b...        0.9995
# 6  Leveraging Artificial Intelligence to Prevent ...        0.9992
# 7  Forbes 2026 AI 50 List | Top Artificial Intell...        0.9990
# 8  Senator Banks raises concerns over Chinese esp...        0.9988
# 9  IN AI: Braun unveils artificial intelligence b...        0.9987
#
#   semantic_score_1_to_5
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# Sablon kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\odev2\semantic_scores_template.csv

# %%
# (3) Jaccard Benzerliği – 16x16 sıralama tutarlılığı matrisi

def jaccard(set_a, set_b):
    if not set_a and not set_b:
        return 1.0
    union = set_a | set_b
    if not union:
        return 0.0
    return len(set_a & set_b) / len(union)


model_names = sorted(similarity_results.keys())
top5_sets = {
    name: {m['doc_id'] for m in similarity_results[name]['top_matches']}
    for name in model_names
}

jaccard_matrix = np.zeros((len(model_names), len(model_names)), dtype=float)
for i, model_i in enumerate(model_names):
    for j, model_j in enumerate(model_names):
        jaccard_matrix[i, j] = jaccard(top5_sets[model_i], top5_sets[model_j])

jaccard_df = pd.DataFrame(jaccard_matrix, index=model_names, columns=model_names)
print('=== (3) JACCARD MATRISI (16x16) ===')
display(jaccard_df.round(3))

jaccard_csv_path = ODEV2_CONFIG['results_dir'] / 'jaccard_matrix.csv'
jaccard_df.to_csv(jaccard_csv_path, encoding='utf-8')
print(f'Kaydedildi: {jaccard_csv_path}')

# Heatmap
plt.figure(figsize=(14, 12))
sns.heatmap(
    jaccard_df,
    annot=False,
    cmap='YlOrRd',
    vmin=0,
    vmax=1,
    square=True,
    cbar_kws={'label': 'Jaccard Benzerligi'},
)
plt.title('Model Siralama Tutarliligi – Jaccard Heatmap (16 Model)')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()

heatmap_path = ODEV2_CONFIG['results_dir'] / 'jaccard_heatmap.png'
plt.savefig(heatmap_path, dpi=150)
plt.show()
print(f'Heatmap kaydedildi: {heatmap_path}')

# En yüksek Jaccard çiftleri (köşegen hariç)
pairs = []
for i in range(len(model_names)):
    for j in range(i + 1, len(model_names)):
        pairs.append((model_names[i], model_names[j], jaccard_matrix[i, j]))
pairs.sort(key=lambda x: x[2], reverse=True)

print('\nEn benzer sonuc ureten model ciftleri (ust 5):')
for a, b, score in pairs[:5]:
    print(f'  {a} <-> {b} : {score:.3f}')
# Out:
# === (3) JACCARD MATRISI (16x16) ===
#                                                 word2vec_lemmatized_cbow_win2_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                           1.000
# word2vec_lemmatized_cbow_win2_dim300.model                                           0.429
# word2vec_lemmatized_cbow_win4_dim100.model                                           1.000
# word2vec_lemmatized_cbow_win4_dim300.model                                           0.429
# word2vec_lemmatized_skipgram_win2_dim100.model                                       0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                       0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                       0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                       0.429
# word2vec_stemmed_cbow_win2_dim100.model                                              0.429
# word2vec_stemmed_cbow_win2_dim300.model                                              0.429
# word2vec_stemmed_cbow_win4_dim100.model                                              0.667
# word2vec_stemmed_cbow_win4_dim300.model                                              0.429
# word2vec_stemmed_skipgram_win2_dim100.model                                          0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                          0.250
# word2vec_stemmed_skipgram_win4_dim100.model                                          0.250
# word2vec_stemmed_skipgram_win4_dim300.model                                          0.250
#
#                                                 word2vec_lemmatized_cbow_win2_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                           0.429
# word2vec_lemmatized_cbow_win2_dim300.model                                           1.000
# word2vec_lemmatized_cbow_win4_dim100.model                                           0.429
# word2vec_lemmatized_cbow_win4_dim300.model                                           1.000
# word2vec_lemmatized_skipgram_win2_dim100.model                                       0.000
# word2vec_lemmatized_skipgram_win2_dim300.model                                       0.000
# word2vec_lemmatized_skipgram_win4_dim100.model                                       0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                       0.250
# word2vec_stemmed_cbow_win2_dim100.model                                              1.000
# word2vec_stemmed_cbow_win2_dim300.model                                              0.667
# word2vec_stemmed_cbow_win4_dim100.model                                              0.429
# word2vec_stemmed_cbow_win4_dim300.model                                              0.429
# word2vec_stemmed_skipgram_win2_dim100.model                                          0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                          0.111
# word2vec_stemmed_skipgram_win4_dim100.model                                          0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                          0.111
#
#                                                 word2vec_lemmatized_cbow_win4_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                           1.000
# word2vec_lemmatized_cbow_win2_dim300.model                                           0.429
# word2vec_lemmatized_cbow_win4_dim100.model                                           1.000
# word2vec_lemmatized_cbow_win4_dim300.model                                           0.429
# word2vec_lemmatized_skipgram_win2_dim100.model                                       0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                       0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                       0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                       0.429
# word2vec_stemmed_cbow_win2_dim100.model                                              0.429
# word2vec_stemmed_cbow_win2_dim300.model                                              0.429
# word2vec_stemmed_cbow_win4_dim100.model                                              0.667
# word2vec_stemmed_cbow_win4_dim300.model                                              0.429
# word2vec_stemmed_skipgram_win2_dim100.model                                          0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                          0.250
# word2vec_stemmed_skipgram_win4_dim100.model                                          0.250
# word2vec_stemmed_skipgram_win4_dim300.model                                          0.250
#
#                                                 word2vec_lemmatized_cbow_win4_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                           0.429
# word2vec_lemmatized_cbow_win2_dim300.model                                           1.000
# word2vec_lemmatized_cbow_win4_dim100.model                                           0.429
# word2vec_lemmatized_cbow_win4_dim300.model                                           1.000
# word2vec_lemmatized_skipgram_win2_dim100.model                                       0.000
# word2vec_lemmatized_skipgram_win2_dim300.model                                       0.000
# word2vec_lemmatized_skipgram_win4_dim100.model                                       0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                       0.250
# word2vec_stemmed_cbow_win2_dim100.model                                              1.000
# word2vec_stemmed_cbow_win2_dim300.model                                              0.667
# word2vec_stemmed_cbow_win4_dim100.model                                              0.429
# word2vec_stemmed_cbow_win4_dim300.model                                              0.429
# word2vec_stemmed_skipgram_win2_dim100.model                                          0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                          0.111
# word2vec_stemmed_skipgram_win4_dim100.model                                          0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                          0.111
#
#                                                 word2vec_lemmatized_skipgram_win2_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                               0.111
# word2vec_lemmatized_cbow_win2_dim300.model                                               0.000
# word2vec_lemmatized_cbow_win4_dim100.model                                               0.111
# word2vec_lemmatized_cbow_win4_dim300.model                                               0.000
# word2vec_lemmatized_skipgram_win2_dim100.model                                           1.000
# word2vec_lemmatized_skipgram_win2_dim300.model                                           0.667
# word2vec_lemmatized_skipgram_win4_dim100.model                                           0.111
# word2vec_lemmatized_skipgram_win4_dim300.model                                           0.250
# word2vec_stemmed_cbow_win2_dim100.model                                                  0.000
# word2vec_stemmed_cbow_win2_dim300.model                                                  0.000
# word2vec_stemmed_cbow_win4_dim100.model                                                  0.111
# word2vec_stemmed_cbow_win4_dim300.model                                                  0.111
# word2vec_stemmed_skipgram_win2_dim100.model                                              0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                              0.667
# word2vec_stemmed_skipgram_win4_dim100.model                                              0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                              0.111
#
#                                                 word2vec_lemmatized_skipgram_win2_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                               0.111
# word2vec_lemmatized_cbow_win2_dim300.model                                               0.000
# word2vec_lemmatized_cbow_win4_dim100.model                                               0.111
# word2vec_lemmatized_cbow_win4_dim300.model                                               0.000
# word2vec_lemmatized_skipgram_win2_dim100.model                                           0.667
# word2vec_lemmatized_skipgram_win2_dim300.model                                           1.000
# word2vec_lemmatized_skipgram_win4_dim100.model                                           0.111
# word2vec_lemmatized_skipgram_win4_dim300.model                                           0.250
# word2vec_stemmed_cbow_win2_dim100.model                                                  0.000
# word2vec_stemmed_cbow_win2_dim300.model                                                  0.000
# word2vec_stemmed_cbow_win4_dim100.model                                                  0.111
# word2vec_stemmed_cbow_win4_dim300.model                                                  0.111
# word2vec_stemmed_skipgram_win2_dim100.model                                              0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                              0.667
# word2vec_stemmed_skipgram_win4_dim100.model                                              0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                              0.111
#
#                                                 word2vec_lemmatized_skipgram_win4_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                               0.250
# word2vec_lemmatized_cbow_win2_dim300.model                                               0.250
# word2vec_lemmatized_cbow_win4_dim100.model                                               0.250
# word2vec_lemmatized_cbow_win4_dim300.model                                               0.250
# word2vec_lemmatized_skipgram_win2_dim100.model                                           0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                           0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                           1.000
# word2vec_lemmatized_skipgram_win4_dim300.model                                           0.667
# word2vec_stemmed_cbow_win2_dim100.model                                                  0.250
# word2vec_stemmed_cbow_win2_dim300.model                                                  0.111
# word2vec_stemmed_cbow_win4_dim100.model                                                  0.250
# word2vec_stemmed_cbow_win4_dim300.model                                                  0.111
# word2vec_stemmed_skipgram_win2_dim100.model                                              0.667
# word2vec_stemmed_skipgram_win2_dim300.model                                              0.250
# word2vec_stemmed_skipgram_win4_dim100.model                                              0.250
# word2vec_stemmed_skipgram_win4_dim300.model                                              0.250
#
#                                                 word2vec_lemmatized_skipgram_win4_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                               0.429
# word2vec_lemmatized_cbow_win2_dim300.model                                               0.250
# word2vec_lemmatized_cbow_win4_dim100.model                                               0.429
# word2vec_lemmatized_cbow_win4_dim300.model                                               0.250
# word2vec_lemmatized_skipgram_win2_dim100.model                                           0.250
# word2vec_lemmatized_skipgram_win2_dim300.model                                           0.250
# word2vec_lemmatized_skipgram_win4_dim100.model                                           0.667
# word2vec_lemmatized_skipgram_win4_dim300.model                                           1.000
# word2vec_stemmed_cbow_win2_dim100.model                                                  0.250
# word2vec_stemmed_cbow_win2_dim300.model                                                  0.111
# word2vec_stemmed_cbow_win4_dim100.model                                                  0.250
# word2vec_stemmed_cbow_win4_dim300.model                                                  0.111
# word2vec_stemmed_skipgram_win2_dim100.model                                              0.667
# word2vec_stemmed_skipgram_win2_dim300.model                                              0.429
# word2vec_stemmed_skipgram_win4_dim100.model                                              0.250
# word2vec_stemmed_skipgram_win4_dim300.model                                              0.250
#
#                                                 word2vec_stemmed_cbow_win2_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                        0.429
# word2vec_lemmatized_cbow_win2_dim300.model                                        1.000
# word2vec_lemmatized_cbow_win4_dim100.model                                        0.429
# word2vec_lemmatized_cbow_win4_dim300.model                                        1.000
# word2vec_lemmatized_skipgram_win2_dim100.model                                    0.000
# word2vec_lemmatized_skipgram_win2_dim300.model                                    0.000
# word2vec_lemmatized_skipgram_win4_dim100.model                                    0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                    0.250
# word2vec_stemmed_cbow_win2_dim100.model                                           1.000
# word2vec_stemmed_cbow_win2_dim300.model                                           0.667
# word2vec_stemmed_cbow_win4_dim100.model                                           0.429
# word2vec_stemmed_cbow_win4_dim300.model                                           0.429
# word2vec_stemmed_skipgram_win2_dim100.model                                       0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                       0.111
# word2vec_stemmed_skipgram_win4_dim100.model                                       0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                       0.111
#
#                                                 word2vec_stemmed_cbow_win2_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                        0.429
# word2vec_lemmatized_cbow_win2_dim300.model                                        0.667
# word2vec_lemmatized_cbow_win4_dim100.model                                        0.429
# word2vec_lemmatized_cbow_win4_dim300.model                                        0.667
# word2vec_lemmatized_skipgram_win2_dim100.model                                    0.000
# word2vec_lemmatized_skipgram_win2_dim300.model                                    0.000
# word2vec_lemmatized_skipgram_win4_dim100.model                                    0.111
# word2vec_lemmatized_skipgram_win4_dim300.model                                    0.111
# word2vec_stemmed_cbow_win2_dim100.model                                           0.667
# word2vec_stemmed_cbow_win2_dim300.model                                           1.000
# word2vec_stemmed_cbow_win4_dim100.model                                           0.429
# word2vec_stemmed_cbow_win4_dim300.model                                           0.667
# word2vec_stemmed_skipgram_win2_dim100.model                                       0.111
# word2vec_stemmed_skipgram_win2_dim300.model                                       0.000
# word2vec_stemmed_skipgram_win4_dim100.model                                       0.000
# word2vec_stemmed_skipgram_win4_dim300.model                                       0.000
#
#                                                 word2vec_stemmed_cbow_win4_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                        0.667
# word2vec_lemmatized_cbow_win2_dim300.model                                        0.429
# word2vec_lemmatized_cbow_win4_dim100.model                                        0.667
# word2vec_lemmatized_cbow_win4_dim300.model                                        0.429
# word2vec_lemmatized_skipgram_win2_dim100.model                                    0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                    0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                    0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                    0.250
# word2vec_stemmed_cbow_win2_dim100.model                                           0.429
# word2vec_stemmed_cbow_win2_dim300.model                                           0.429
# word2vec_stemmed_cbow_win4_dim100.model                                           1.000
# word2vec_stemmed_cbow_win4_dim300.model                                           0.667
# word2vec_stemmed_skipgram_win2_dim100.model                                       0.429
# word2vec_stemmed_skipgram_win2_dim300.model                                       0.250
# word2vec_stemmed_skipgram_win4_dim100.model                                       0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                       0.111
#
#                                                 word2vec_stemmed_cbow_win4_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                        0.429
# word2vec_lemmatized_cbow_win2_dim300.model                                        0.429
# word2vec_lemmatized_cbow_win4_dim100.model                                        0.429
# word2vec_lemmatized_cbow_win4_dim300.model                                        0.429
# word2vec_lemmatized_skipgram_win2_dim100.model                                    0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                    0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                    0.111
# word2vec_lemmatized_skipgram_win4_dim300.model                                    0.111
# word2vec_stemmed_cbow_win2_dim100.model                                           0.429
# word2vec_stemmed_cbow_win2_dim300.model                                           0.667
# word2vec_stemmed_cbow_win4_dim100.model                                           0.667
# word2vec_stemmed_cbow_win4_dim300.model                                           1.000
# word2vec_stemmed_skipgram_win2_dim100.model                                       0.250
# word2vec_stemmed_skipgram_win2_dim300.model                                       0.111
# word2vec_stemmed_skipgram_win4_dim100.model                                       0.000
# word2vec_stemmed_skipgram_win4_dim300.model                                       0.000
#
#                                                 word2vec_stemmed_skipgram_win2_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win2_dim300.model                                            0.250
# word2vec_lemmatized_cbow_win4_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win4_dim300.model                                            0.250
# word2vec_lemmatized_skipgram_win2_dim100.model                                        0.250
# word2vec_lemmatized_skipgram_win2_dim300.model                                        0.250
# word2vec_lemmatized_skipgram_win4_dim100.model                                        0.667
# word2vec_lemmatized_skipgram_win4_dim300.model                                        0.667
# word2vec_stemmed_cbow_win2_dim100.model                                               0.250
# word2vec_stemmed_cbow_win2_dim300.model                                               0.111
# word2vec_stemmed_cbow_win4_dim100.model                                               0.429
# word2vec_stemmed_cbow_win4_dim300.model                                               0.250
# word2vec_stemmed_skipgram_win2_dim100.model                                           1.000
# word2vec_stemmed_skipgram_win2_dim300.model                                           0.429
# word2vec_stemmed_skipgram_win4_dim100.model                                           0.111
# word2vec_stemmed_skipgram_win4_dim300.model                                           0.111
#
#                                                 word2vec_stemmed_skipgram_win2_dim300.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win2_dim300.model                                            0.111
# word2vec_lemmatized_cbow_win4_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win4_dim300.model                                            0.111
# word2vec_lemmatized_skipgram_win2_dim100.model                                        0.667
# word2vec_lemmatized_skipgram_win2_dim300.model                                        0.667
# word2vec_lemmatized_skipgram_win4_dim100.model                                        0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                        0.429
# word2vec_stemmed_cbow_win2_dim100.model                                               0.111
# word2vec_stemmed_cbow_win2_dim300.model                                               0.000
# word2vec_stemmed_cbow_win4_dim100.model                                               0.250
# word2vec_stemmed_cbow_win4_dim300.model                                               0.111
# word2vec_stemmed_skipgram_win2_dim100.model                                           0.429
# word2vec_stemmed_skipgram_win2_dim300.model                                           1.000
# word2vec_stemmed_skipgram_win4_dim100.model                                           0.250
# word2vec_stemmed_skipgram_win4_dim300.model                                           0.250
#
#                                                 word2vec_stemmed_skipgram_win4_dim100.model  \
# word2vec_lemmatized_cbow_win2_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win2_dim300.model                                            0.111
# word2vec_lemmatized_cbow_win4_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win4_dim300.model                                            0.111
# word2vec_lemmatized_skipgram_win2_dim100.model                                        0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                        0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                        0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                        0.250
# word2vec_stemmed_cbow_win2_dim100.model                                               0.111
# word2vec_stemmed_cbow_win2_dim300.model                                               0.000
# word2vec_stemmed_cbow_win4_dim100.model                                               0.111
# word2vec_stemmed_cbow_win4_dim300.model                                               0.000
# word2vec_stemmed_skipgram_win2_dim100.model                                           0.111
# word2vec_stemmed_skipgram_win2_dim300.model                                           0.250
# word2vec_stemmed_skipgram_win4_dim100.model                                           1.000
# word2vec_stemmed_skipgram_win4_dim300.model                                           0.667
#
#                                                 word2vec_stemmed_skipgram_win4_dim300.model
# word2vec_lemmatized_cbow_win2_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win2_dim300.model                                            0.111
# word2vec_lemmatized_cbow_win4_dim100.model                                            0.250
# word2vec_lemmatized_cbow_win4_dim300.model                                            0.111
# word2vec_lemmatized_skipgram_win2_dim100.model                                        0.111
# word2vec_lemmatized_skipgram_win2_dim300.model                                        0.111
# word2vec_lemmatized_skipgram_win4_dim100.model                                        0.250
# word2vec_lemmatized_skipgram_win4_dim300.model                                        0.250
# word2vec_stemmed_cbow_win2_dim100.model                                               0.111
# word2vec_stemmed_cbow_win2_dim300.model                                               0.000
# word2vec_stemmed_cbow_win4_dim100.model                                               0.111
# word2vec_stemmed_cbow_win4_dim300.model                                               0.000
# word2vec_stemmed_skipgram_win2_dim100.model                                           0.111
# word2vec_stemmed_skipgram_win2_dim300.model                                           0.250
# word2vec_stemmed_skipgram_win4_dim100.model                                           0.667
# word2vec_stemmed_skipgram_win4_dim300.model                                           1.000
# Kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\odev2\jaccard_matrix.csv
# Heatmap kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\odev2\jaccard_heatmap.png
#
# En benzer sonuc ureten model ciftleri (ust 5):
#   word2vec_lemmatized_cbow_win2_dim100.model <-> word2vec_lemmatized_cbow_win4_dim100.model : 1.000
#   word2vec_lemmatized_cbow_win2_dim300.model <-> word2vec_lemmatized_cbow_win4_dim300.model : 1.000
#   word2vec_lemmatized_cbow_win2_dim300.model <-> word2vec_stemmed_cbow_win2_dim100.model : 1.000
#   word2vec_lemmatized_cbow_win4_dim300.model <-> word2vec_stemmed_cbow_win2_dim100.model : 1.000
#   word2vec_lemmatized_cbow_win2_dim100.model <-> word2vec_stemmed_cbow_win4_dim100.model : 0.667
