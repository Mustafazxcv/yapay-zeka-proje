# %% [markdown]
# # Haber Başlığı Ödev Projesi
#
# Bu notebook, **veri çekme scriptlerinden sonra** çalışır.
#
# ## Öğrenciler
# - Mustafa Mete / 2202131015
# - Emine Avcu / 2202131006
#
# ## Akış
# 1. Parametreleri tanımla ve ekrana yazdır.
# 2. Ham veriyi oku.
# 3. Başlıkları normalize et (NLTK stopwords kullanarak).
# 4. Duplicate çiftleri TF-IDF + cosine ile bul.
# 5. Sonuçları kaydet.

# %%
import csv
import html
import json
import re
import unicodedata
from pathlib import Path
from pprint import pprint

import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

print('[1/11] Kutuphaneler yuklendi.')
# Out:
# [1/11] Kutuphaneler yuklendi.

# %%
# Tum pipeline parametreleri tek bir yapida tutuluyor.
CONFIG = {
    'input_json': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/all/headlines_all.json'),
    'normalized_out_csv': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/processed/all/headlines_normalized_all.csv'),
    'normalized_out_json': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/processed/all/headlines_normalized_all.json'),
    'pairs_out_csv': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/results/all/duplicate_pairs_all.csv'),
    'pairs_out_json': Path(r'C:/Users/musta/OneDrive/Masaüstü/Yapay Zeka Dersi/data/results/all/duplicate_pairs_all.json'),
    'threshold': 0.85,
    'language': 'english'
}

print('[2/11] Konfigurasyon hazirlandi.')
# Out:
# [2/11] Konfigurasyon hazirlandi.

# %%
# Parametreleri acik ve okunabilir sekilde yazdir.
print('=== PIPELINE PARAMETRELERI ===')
print(f"input_json          : {CONFIG['input_json']}")
print(f"normalized_out_csv  : {CONFIG['normalized_out_csv']}")
print(f"normalized_out_json : {CONFIG['normalized_out_json']}")
print(f"pairs_out_csv       : {CONFIG['pairs_out_csv']}")
print(f"pairs_out_json      : {CONFIG['pairs_out_json']}")
print(f"threshold           : {CONFIG['threshold']:.2f}")
print(f"language            : {CONFIG['language']}")
# Out:
# === PIPELINE PARAMETRELERI ===
# input_json          : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\all\headlines_all.json
# normalized_out_csv  : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# normalized_out_json : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json
# pairs_out_csv       : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv
# pairs_out_json      : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json
# threshold           : 0.85
# language            : english

# %%
# Gerekli NLTK corpus'unu indir.
# Not: Daha once indirildiyse tekrar indirmez.
nltk.download('stopwords', quiet=True)

# Dile gore stopwords seti olustur.
LANG_STOPWORDS = set(stopwords.words(CONFIG['language']))
print(f'Stopwords yuklendi. Toplam: {len(LANG_STOPWORDS)}')
# Out:
# Stopwords yuklendi. Toplam: 198

# %%
VERBOSE_NORMALIZE = True

# Baslik sonundaki kaynak etiketlerini temizler.
def strip_source_suffix(title: str) -> str:
    title = re.sub(r'\s*-\s*[^-]{2,80}$', '', title).strip()
    title = re.sub(r'\s*\|\s*[^|]{2,80}$', '', title).strip()
    return title

# Turkce karakterlerin ASCII benzeri formunu alir.
def remove_accents(text: str) -> str:
    normalized = unicodedata.normalize('NFKD', text)
    return ''.join(ch for ch in normalized if not unicodedata.combining(ch))

NOISE_TERMS = {
    'live', 'update', 'updates', 'video', 'photos', 'podcast', 'analysis',
    'opinion', 'exclusive', 'new', 'breaking', 'watch', 'report', 'latest'
}

# Tek bir basligi normalize eder.
def normalize_title(text: str) -> str:
    original = text

    text = html.unescape(text)
    text = strip_source_suffix(text)
    text = remove_accents(text).lower()
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)
    text = re.sub(r'\[[^\]]*\]|\([^\)]*\)', ' ', text)
    text = re.sub(r'[^\w\s]', ' ', text)

    tokens = re.findall(r'[a-z0-9]+', text)

    cleaned_tokens = []
    for token in tokens:
        if token in LANG_STOPWORDS:
            continue
        if token in NOISE_TERMS:
            continue
        if token.isdigit():
            continue
        if len(token) < 3:
            continue
        cleaned_tokens.append(token)

    result = ' '.join(cleaned_tokens).strip()

    if VERBOSE_NORMALIZE:
        print(f"[normalize_title] Orijinal: {original}")
        print(f"[normalize_title] Token sayisi: {len(tokens)}")
        print(f"[normalize_title] Sonuc: {result}")

    return result


def write_csv(path: Path, rows, fieldnames):
    print(f"[write_csv] Yaziliyor: {path}")
    print(f"[write_csv] Satir sayisi: {len(rows)}")

    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open('w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

    print("[write_csv] Tamamlandi")


def write_json(path: Path, data):
    print(f"[write_json] Yaziliyor: {path}")
    print(f"[write_json] Kayit sayisi: {len(data) if isinstance(data, list) else 'N/A'}")

    path.parent.mkdir(parents=True, exist_ok=True)

    path.write_text(
        json.dumps(data, ensure_ascii=False, indent=2),
        encoding='utf-8'
    )

    print("[write_json] Tamamlandi")


print('[4/11] Yardimci fonksiyonlar hazirlandi.')
# Out:
# [4/11] Yardimci fonksiyonlar hazirlandi.

# %%
input_path = CONFIG['input_json']
if not input_path.exists():
    raise FileNotFoundError(f'Girdi dosyasi bulunamadi: {input_path}')

raw_records = json.loads(input_path.read_text(encoding='utf-8'))
if not isinstance(raw_records, list):
    raise ValueError('Girdi JSON formati hatali. Liste bekleniyor.')

print(f'Ham kayit sayisi: {len(raw_records)}')
# Out:
# Ham kayit sayisi: 2805

# %%
normalized_records = []

for item in raw_records:
    # Bos veya eksik title kayitlarini atla.
    title = (item.get('title') or '').strip()
    if not title:
        continue

    normalized = normalize_title(title)
    if not normalized:
        continue

    normalized_records.append(
        {
            'title': title,
            'normalized_title': normalized,
            'source': item.get('source') or '',
            'link': item.get('link') or '',
            'pubDate': item.get('pubDate') or '',
        }
    )

print(f'Normalize kayit sayisi: {len(normalized_records)}')
print('Ornek normalize kayit:')
pprint(normalized_records[:2])
# Out:
# [normalize_title] Orijinal: U.S. stocks clock best month since 2020 as Wall Street shakes off Iran oil shock
# [normalize_title] Token sayisi: 16
# [normalize_title] Sonuc: stocks clock best month since wall street shakes iran oil shock
# [normalize_title] Orijinal: FAA chief predicts fewer air traffic control delays this summer
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: faa chief predicts fewer air traffic control delays summer
# [normalize_title] Orijinal: Stephen King’s 2 New Shows In 2026 Will Tell The Same Dark Story
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: stephen king shows tell dark story
# [normalize_title] Orijinal: Tennessee man uses lasers to make the world’s thinnest car
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: tennessee man uses lasers make world thinnest car
# [normalize_title] Orijinal: Chicago police officer John Bartholomew's accused killer ordered held until murder trial
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: chicago police officer john bartholomew accused killer ordered held murder trial
# [normalize_title] Orijinal: Countries that have banned social media for teenagers — See the world map
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: countries banned social media teenagers see world map
# [normalize_title] Orijinal: Under-Oath Elon Musk Seems to Run a Different Company Than Public-Figure Elon Musk
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: oath elon musk seems run different company public
# [normalize_title] Orijinal: The 21 Best New Beauty Products That Launched in April 2026
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: best beauty products launched april
# [normalize_title] Orijinal: JPMorgan Chase & Co. Issues Positive Forecast for Seagate Technology (NASDAQ:STX) Stock Price
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: jpmorgan chase issues positive forecast seagate technology stock price
# [normalize_title] Orijinal: StoneCo (NASDAQ:STNE) Sets New 12-Month Low – Here’s What Happened
# [normalize_title] Token sayisi: 4
# [normalize_title] Sonuc: stoneco sets
# [normalize_title] Orijinal: NOV Sees Unusually Large Options Volume (NYSE:NOV)
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: nov sees unusually large options volume
# [normalize_title] Orijinal: 12 Information Technology Stocks Moving In Thursday's After-Market Session
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: information technology stocks moving thursday
# [normalize_title] Orijinal: Zedge (NYSEAMERICAN:ZDGE) Shares Cross Above 50 Day Moving Average – What’s Next?
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: zedge shares cross day moving average next
# [normalize_title] Orijinal: Novanta (NASDAQ:NOVT) Stock Price Crosses Above 50-Day Moving Average – Should You Sell?
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: novanta stock price crosses
# [normalize_title] Orijinal: Fairfax Financial Holdings Limited: Financial Results for the First Quarter
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: fairfax financial holdings limited financial results first quarter
# [normalize_title] Orijinal: In Guatemala, new AI technology will be ‘listening’ for illegal deforestation
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: guatemala technology listening illegal deforestation
# [normalize_title] Orijinal: Skyline 7 member pleads guilty in Oregon AAPI burglaries
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: skyline member pleads guilty oregon aapi burglaries
# [normalize_title] Orijinal: TriNet (TNET) Q1 2026 Earnings Call Transcript
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: trinet earnings call transcript
# [normalize_title] Orijinal: Judge tells Elon Musk to cool it on the robot apocalypse talk
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: apple given vision pro refresh flop
# [normalize_title] Orijinal: More Gemini features are coming to Google TV - TechCrunch
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: gemini features coming google
# [normalize_title] Orijinal: SpaceX rocket debris could slam into the moon: Here's what you need to know - Space
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: spacex rocket debris could slam moon need know
# [normalize_title] Orijinal: Box Office: ‘Devil Wears Prada 2’ Poised for Massive Debut Above $80 Million Domestically, $180 Million Globally - Variety
# [normalize_title] Token sayisi: 17
# [normalize_title] Sonuc: box office devil wears prada poised massive debut million domestically million globally
# [normalize_title] Orijinal: Eating healthy may not keep ultraprocessed food from increasing dementia - CNN
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: eating healthy may keep ultraprocessed food increasing dementia
# [normalize_title] Orijinal: The Most Common Warning Signs Of Rectal Cancer - HuffPost
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: common warning signs rectal cancer
# [normalize_title] Orijinal: Core rocket for upcoming Artemis III mission arrives at Kennedy Space Center - ABC News - Breaking News, Latest News and Videos
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: core rocket upcoming artemis iii mission arrives kennedy space center abc news
# [normalize_title] Orijinal: Wisconsin could be in for ‘a big year’ for Lyme disease as tick bites soar - WPR
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: wisconsin could big year lyme disease tick bites soar
# [normalize_title] Orijinal: AI Spots Pancreatic Cancer Years Before It Shows Up, Study Finds - Bloomberg.com
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: spots pancreatic cancer years shows study finds
# [normalize_title] Orijinal: French teen charged in Singapore over a vending machine straw-licking video
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: french teen charged singapore vending machine straw
# [normalize_title] Orijinal: David Allan Coe, who wrote 'Take This Job and Shove It' dies at 86
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: david allan coe wrote take job shove dies
# [normalize_title] Orijinal: A North Texas man faces execution as his cousin claims he was the shooter
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: north texas man faces execution cousin claims shooter
# [normalize_title] Orijinal: Romanian man sentenced to prison for swatting spree targeting dozens of US officials
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: romanian man sentenced prison swatting spree targeting dozens officials
# [normalize_title] Orijinal: State alleges multiple violations against Urban Air facility after 6-year-old girl killed in go-kart crash
# [normalize_title] Token sayisi: 16
# [normalize_title] Sonuc: state alleges multiple violations urban air facility year old girl killed
# [normalize_title] Orijinal: Florida legislature approves new congressional map that could give Republicans 4 more seats
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: florida legislature approves congressional map could give republicans seats
# [normalize_title] Orijinal: Trump says James Comey's Instagram post represents 'tremendous danger'
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: trump says james comey instagram post represents tremendous danger
# [normalize_title] Orijinal: Fed chair Jerome Powell says he will stay on central bank's board after term expires next month
# [normalize_title] Token sayisi: 18
# [normalize_title] Sonuc: fed chair jerome powell says stay central bank board term expires next month
# [normalize_title] Orijinal: Pakistan opens up road trade routes into Iran amid Hormuz blockade
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: pakistan opens road trade routes iran amid hormuz blockade
# [normalize_title] Orijinal: Myanmar’s blanket prison term reduction trims Aung San Suu Kyi’s sentence
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: myanmar blanket prison term reduction trims aung san suu kyi sentence
# [normalize_title] Orijinal: Iran war: What’s happening on day 62 as Trump asks Iran to ‘give up’?
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: iran war happening day trump asks iran give
# [normalize_title] Orijinal: Could the US-Iran war become a protracted ‘frozen’ conflict?
# [normalize_title] Token sayisi: 3
# [normalize_title] Sonuc: could
# [normalize_title] Orijinal: Iranian officials to miss FIFA Congress over alleged mistreatment in Canada
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: iranian officials miss fifa congress alleged mistreatment canada
# [normalize_title] Orijinal: Why is India turning to crocodiles and snakes to ‘fence’ Bangladesh border?
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: india turning crocodiles snakes fence bangladesh border
# [normalize_title] Orijinal: Can the EU’s Article 42.7 offer Europe NATO-like collective defence?
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: article offer europe nato
# [normalize_title] Orijinal: Iran war live: Trump urges Tehran to ‘just give up’ as oil prices surge
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: iran war trump urges tehran give oil prices surge
# [normalize_title] Orijinal: Israeli military speedboats block Gaza-bound aid ship
# [normalize_title] Token sayisi: 5
# [normalize_title] Sonuc: israeli military speedboats block gaza
# [normalize_title] Orijinal: UAE quits OPEC: What that means for the Gulf, energy markets and beyond
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: uae quits opec means gulf energy markets beyond
# [normalize_title] Orijinal: Switch emulator Ryujinx shuts down development after “contact by Nintendo”
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: switch emulator ryujinx shuts development contact nintendo
# [normalize_title] Orijinal: Lab owner pleads guilty to faking COVID test results during pandemic
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: lab owner pleads guilty faking covid test results pandemic
# [normalize_title] Orijinal: AI digests repetitive scatological document into profound “poop” podcast
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: digests repetitive scatological document profound poop
# [normalize_title] Orijinal: Crook made millions by breaking into execs’ Office365 inboxes, feds say
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: crook made millions execs office365 inboxes feds say
# [normalize_title] Orijinal: OpenAI unveils easy voice assistant creation at 2024 developer event
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: openai unveils easy voice assistant creation developer event
# [normalize_title] Orijinal: T-Mobile pays $16 million fine for three years’ worth of data breaches
# [normalize_title] Token sayisi: 1
# [normalize_title] Sonuc:
# [normalize_title] Orijinal: Toxic chemicals from Ohio train derailment lingered in buildings for months
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: toxic chemicals ohio train derailment lingered buildings months
# [normalize_title] Orijinal: “Extreme” Broadcom-proposed price hike would up VMware costs 1,050%, AT&T says
# [normalize_title] Token sayisi: 2
# [normalize_title] Sonuc: extreme broadcom
# [normalize_title] Orijinal: Car dealers renew their opposition to EV mandates
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: car dealers renew opposition mandates
# [normalize_title] Orijinal: eBay listings for banned chemicals shielded by Section 230, judge rules
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: ebay listings banned chemicals shielded section judge rules
# [normalize_title] Orijinal: Analysis: US blockade starts squeezing Iran's oil
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: blockade starts squeezing iran oil
# [normalize_title] Orijinal: Brent crude tops $125 a barrel on Iran war worries
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: brent crude tops barrel iran war worries
# [normalize_title] Orijinal: Hegseth faces more grilling from lawmakers on the Iran war
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: hegseth faces grilling lawmakers iran war
# [normalize_title] Orijinal: Voting rights ruling means a big shakeup is coming for Black Caucus
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: voting rights ruling means big shakeup coming black caucus
# [normalize_title] Orijinal: Ford aircraft carrier is set to end record-long time at sea
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: ford aircraft carrier set end record
# [normalize_title] Orijinal: Prosecutors say singer D4vd stabbed 14-year-old to death
# [normalize_title] Token sayisi: 7
# [normalize_title] Sonuc: prosecutors say singer d4vd stabbed year
# [normalize_title] Orijinal: Supreme Court ruling is set to reshape American politics
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: bmw porsche china problem ones
# [normalize_title] Orijinal: LA fires: Landlords are price gouging, says 'Selling Sunset' star
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: fires landlords price gouging says selling sunset star
# [normalize_title] Orijinal: Blockchain giant Chainalysis acquires AI agent startup Alterya
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: blockchain giant chainalysis acquires agent startup alterya
# [normalize_title] Orijinal: Why investors shouldn't worry about stretched stock market valuations: BofA
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: investors worry stretched stock market valuations bofa
# [normalize_title] Orijinal: Why middle managers are valuable to companies and their employees
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: middle managers valuable companies employees
# [normalize_title] Orijinal: People can bet on the Los Angeles wildfires. It's a sign of the times.
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: people bet los angeles wildfires sign times
# [normalize_title] Orijinal: Blue Origin cancels rocket launch because of 'vehicle subsystem issue'
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: blue origin cancels rocket launch vehicle subsystem issue
# [normalize_title] Orijinal: Mark Zuckerberg enters his next era as Trump takes office
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: mark zuckerberg enters next era trump takes office
# [normalize_title] Orijinal: Celebrities who lost homes in LA, Palisades fires: Full list
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: celebrities lost homes palisades fires full list
# [normalize_title] Orijinal: 5 do's and don'ts to land a job in the private-credit boom
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: land job private
# [normalize_title] Orijinal: Con 5 preguntas random te diré qué furro de la LigaMX te representa
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: con preguntas random dire que furro ligamx representa
# [normalize_title] Orijinal: Elige entre estos colores y te diré a qué país pertenece realmente tu alma
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: elige entre estos colores dire que pais pertenece realmente alma
# [normalize_title] Orijinal: Test de Stray Kids: Crea una playlist basada en tu personalidad
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: test stray kids crea una playlist basada personalidad
# [normalize_title] Orijinal: Test: ¿Qué personaje de Helluva Boss eres?
# [normalize_title] Token sayisi: 7
# [normalize_title] Sonuc: test que personaje helluva boss eres
# [normalize_title] Orijinal: Fórmula 1 2026: ¿Quién es el piloto mejor pagado?
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: formula quien piloto mejor pagado
# [normalize_title] Orijinal: ¿Qué personaje de Jacob Elordi te rompería el corazón?
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: que personaje jacob elordi romperia corazon
# [normalize_title] Orijinal: Elige un montón de objetos azul bebé y te diremos qué parte de tu infancia no has sanado
# [normalize_title] Token sayisi: 18
# [normalize_title] Sonuc: elige monton objetos azul bebe diremos que parte infancia sanado
# [normalize_title] Orijinal: Test De Personalidad: ¿Qué Therian Serías?
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: test personalidad que therian serias
# [normalize_title] Orijinal: 11 ideas de pasteles para cumplir 25 y sentirte main character
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: ideas pasteles para cumplir sentirte main character
# [normalize_title] Orijinal: Dinos tu personalidad y te diremos tu deporte invernal
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: dinos personalidad diremos deporte invernal
# [normalize_title] Orijinal: Comey appears in court after his indictment for allegedly threatening Trump
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: comey appears court indictment allegedly threatening trump
# [normalize_title] Orijinal: King Charles III, Queen Camilla visit New York City
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: king charles iii queen camilla visit york city
# [normalize_title] Orijinal: Watch key moments from Pete Hegseth's testimony about Pentagon funding, Iran
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: devil wears old navy inside hollywood favorite movie marketing blitz
# [normalize_title] Orijinal: Logan Paul’s $635,000 NFT ‘Mistake’ Plunges 99% — Where Are Other Celebrity NFTs Now?
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: logan paul nft mistake plunges celebrity nfts
# [normalize_title] Orijinal: Riot Faces Growing Pressure To Move From Bitcoin Mining to AI
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: riot faces growing pressure move bitcoin mining
# [normalize_title] Orijinal: Altcoin Sell Pressure Hits 5-Year Extreme — Is This the Bottom Signal Investors Have Waited For?
# [normalize_title] Token sayisi: 5
# [normalize_title] Sonuc: altcoin sell pressure hits
# [normalize_title] Orijinal: Ethereum (ETH) Price Can't Hold $2,000 — It May Get Worse Before It Gets Better
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: ethereum price hold may get worse gets better
# [normalize_title] Orijinal: ORCA Price Jumps 70% as Nansen NX8 Boosts Exposure — What’s Next for the Token?
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: orca price jumps nansen nx8 boosts exposure next token
# [normalize_title] Orijinal: XRP Price Analysis: Why $2 Remains a ‘Pipe Dream’ Amid Lingering Bearish Sentiment
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: xrp price remains pipe dream amid lingering bearish sentiment
# [normalize_title] Orijinal: Hyperliquid vs Aster: An Honest Analysis
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: hyperliquid aster honest
# [normalize_title] Orijinal: 100x Leverage Isn’t the Problem — Your Position Sizing Is
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: 100x leverage problem position sizing
# [normalize_title] Orijinal: Perps Account for 90% of Crypto Market Behavior
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: perps account crypto market behavior
# [normalize_title] Orijinal: Who Really Controls Aster Token?
# [normalize_title] Token sayisi: 5
# [normalize_title] Sonuc: really controls aster token
# [normalize_title] Orijinal: 'Apprentice' reboot being explored at Amazon
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: apprentice reboot explored amazon
# [normalize_title] Orijinal: Melora Hardin reveals one classic 'Office' scene with Steve Carell was '90 percent improvised'
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: melora hardin reveals one classic office scene steve carell percent improvised
# [normalize_title] Orijinal: Sinbad announces return to comedy stage 5 years after stroke: ‘I'm gonna be talking more trash than I ever talked’
# [normalize_title] Token sayisi: 21
# [normalize_title] Sonuc: sinbad announces return comedy stage years stroke gonna talking trash ever talked
# [normalize_title] Orijinal: 'Survivor 50' recap: Rick Devens goes Beast mode!
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: survivor recap rick devens goes beast mode
# [normalize_title] Orijinal: D4vd ordered body bag and chainsaws after allegedly killing Celeste Rivas Hernandez, prosecutors claim
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: d4vd ordered body bag chainsaws allegedly killing celeste rivas hernandez prosecutors claim
# [normalize_title] Orijinal: Josh O'Connor reveals 'amazing' advice he got from Steven Spielberg — that was actually a big mix-up
# [normalize_title] Token sayisi: 17
# [normalize_title] Sonuc: josh connor reveals amazing advice got steven spielberg actually big mix
# [normalize_title] Orijinal: Ving Rhames treated for 'unconfirmed medical condition' following collapse at L.A. restaurant
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: ving rhames treated unconfirmed medical condition following collapse restaurant
# [normalize_title] Orijinal: ‘The Valley’ star reacts to ex Michelle Saniei’s romance with Dr. Dre: ‘Was wondering why’ daughter got new Beats
# [normalize_title] Token sayisi: 20
# [normalize_title] Sonuc: valley star reacts michelle saniei romance dre wondering daughter got beats
# [normalize_title] Orijinal: Why Christopher Nolan's 'The Odyssey' won't be longer than 'Oppenheimer'
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: christopher nolan odyssey longer oppenheimer
# [normalize_title] Orijinal: 'Days of Our Lives' star Patrick Muldoon's cause of death revealed
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: days lives star patrick muldoon cause death revealed
# [normalize_title] Orijinal: Howden's goal in double-OT lifts Golden Knights over Mammoth - ESPN
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: howden goal double lifts golden knights mammoth
# [normalize_title] Orijinal: Cavs let Schroder cook in 4th, take 3-2 series lead over Raptors - ESPN
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: cavs let schroder cook 4th take series lead raptors
# [normalize_title] Orijinal: Rockets outlast Lakers in Reaves' return to force Game 6 - ESPN
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: rockets outlast lakers reaves return force game
# [normalize_title] Orijinal: Crosby hopes end of Penguins' season isn't end with Malkin - ESPN
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: crosby hopes end penguins season end malkin
# [normalize_title] Orijinal: Pistons top Magic as Cunningham, Banchero each drop 45 - ESPN
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: pistons top magic cunningham banchero drop
# [normalize_title] Orijinal: Church robs Pirates of would-be walk-off, saves Cardinals win - ESPN
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: church robs pirates would walk saves cardinals win
# [normalize_title] Orijinal: Source: Some LIV players exploring potential of PGA Tour return - ESPN
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: source liv players exploring potential pga tour return
# [normalize_title] Orijinal: Cam York scores in OT as Flyers eliminate Penguins in Game 6 - ESPN
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: cam york scores flyers eliminate penguins game
# [normalize_title] Orijinal: 2026 NFL draft: Ranking the 100 best picks, steals, fits - ESPN
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: nfl draft ranking best picks steals fits
# [normalize_title] Orijinal: PCB hands Umar Akmal three-year ban from all cricket | ESPNcricinfo.com
# [normalize_title] Token sayisi: 5
# [normalize_title] Sonuc: pcb hands umar akmal three
# [normalize_title] Orijinal: Akram's yorkers, Hegg's hits, and Chapple's 6 for 18 | ESPNcricinfo.com
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: akram yorkers hegg hits chapple
# [normalize_title] Orijinal: 'It was the first time we realised we can also cry after winning a game'
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: first time realised also cry winning game
# [normalize_title] Orijinal: Five famous people (and one cat) you didn't know have ESPNcricinfo profiles | ESPNcricinfo.com
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: five famous people know espncricinfo profiles
# [normalize_title] Orijinal: Sri Lanka don't win the 1996 World Cup | ESPNcricinfo.com
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: sri lanka win world cup
# [normalize_title] Orijinal: I'm fighting my own benchmarks - R Ashwin | ESPNcricinfo.com
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: fighting benchmarks
# [normalize_title] Orijinal: The Coronavirus soap opera, starring KP, Warnie, Mahela | ESPNcricinfo.com
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: coronavirus soap opera starring warnie mahela
# [normalize_title] Orijinal: Five CSK games only hardcore fans will remember | ESPNcricinfo.com
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: five csk games hardcore fans remember
# [normalize_title] Orijinal: 'This is a ball the whole world will remember' - Saeed Ajmal v Sachin Tendulkar revisited | ESPNcricinfo.com
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: ball whole world remember
# [normalize_title] Orijinal: What we learned from watching the 1992 World Cup final in full again | ESPNcricinfo.com
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: learned watching world cup final full
# [normalize_title] Orijinal: Why a former SoftBank partner is tackling mid-career drop-off for working mothers
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: former softbank partner tackling mid career drop
# [normalize_title] Orijinal: Unprofitable companies needed to be profitable yesterday
# [normalize_title] Token sayisi: 7
# [normalize_title] Sonuc: unprofitable companies needed profitable yesterday
# [normalize_title] Orijinal: Elon Musk crows as German authorities start treating greenwashing as fraud
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: elon musk crows german authorities start treating greenwashing fraud
# [normalize_title] Orijinal: A new report shows how badly the Trump administration slashed the U.S.’s climate credentials
# [normalize_title] Token sayisi: 16
# [normalize_title] Sonuc: shows badly trump administration slashed climate credentials
# [normalize_title] Orijinal: Buybacks vs dividends? In market downturns, the rules may change
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: buybacks dividends market downturns rules may change
# [normalize_title] Orijinal: Why Tinder wants to end the FDA’s discriminatory blood donor policy
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: tinder wants end fda discriminatory blood donor policy
# [normalize_title] Orijinal: The forgotten true story behind Memorial Day—and why it matters now more than ever
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: forgotten true story behind memorial day matters ever
# [normalize_title] Orijinal: 4 vital steps that U.S. CEOs must take in the economic battle with China
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: vital steps ceos must take economic battle china
# [normalize_title] Orijinal: The next Silicon Valley may not exist. Here’s what smaller hubs can do to attract VC dollars
# [normalize_title] Token sayisi: 18
# [normalize_title] Sonuc: next silicon valley may exist smaller hubs attract dollars
# ...
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: google cloud revenue hits search dominance fading
# [normalize_title] Orijinal: Amazon reports increased 1Q profits, net sales fuelled by cloud computing demand - Borneo Bulletin
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: amazon reports increased profits net sales fuelled cloud computing demand
# [normalize_title] Orijinal: University of Washington CS professor explains what's changing for young software engineers - Business Insider
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc: university washington professor explains changing young software engineers
# [normalize_title] Orijinal: AWS CEO suggests AI will shift the landscape of software engineering jobs - Latest news from Azerbaijan
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: aws ceo suggests shift landscape software engineering jobs
# [normalize_title] Orijinal: AWS CEO dismisses AI job loss fears, says Amazon plans to hire 11,000 interns in 2026 - Yahoo News Malaysia
# [normalize_title] Token sayisi: 17
# [normalize_title] Sonuc: aws ceo dismisses job loss fears says amazon plans hire interns
# [normalize_title] Orijinal: What skills drive a senior software engineer’s work at Yahoo? - Silicon Republic
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: skills drive senior software engineer work yahoo
# [normalize_title] Orijinal: King Charles meets with US tech leaders, talks startup challenges - Reuters
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: king charles meets tech leaders talks startup challenges
# [normalize_title] Orijinal: ‘Lovable mafia’: Meet the founders emerging from Europe’s hottest AI startup - Sifted
# [normalize_title] Token sayisi: 12
# [normalize_title] Sonuc: lovable mafia meet founders emerging europe hottest startup
# [normalize_title] Orijinal: DeepMind alumni start dozens of European startups in last 18 months, new data shows - Tech.eu
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: deepmind alumni start dozens european startups last months data shows
# [normalize_title] Orijinal: China Moves to Block US Capital in Its AI Startups: The New Wall Around Tech Talent and Technology - QUASA Connect
# [normalize_title] Token sayisi: 18
# [normalize_title] Sonuc: china moves block capital startups wall around tech talent technology
# [normalize_title] Orijinal: Startup Week returns to Columbus at Cohatch Polaris - The Business Journals
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: startup week returns columbus cohatch polaris
# [normalize_title] Orijinal: AI fuels rise of ‘solopreneurs’ says Stripe as startups scale faster with fewer staff - Business Post
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: fuels rise solopreneurs says stripe startups scale faster fewer staff
# [normalize_title] Orijinal: Week 18’s Biggest Startup Funding Rounds in Latin America, Led by CloudWalk, With Big Bets on Fintech - Techloy
# [normalize_title] Token sayisi: 18
# [normalize_title] Sonuc: week biggest startup funding rounds latin america led cloudwalk big bets fintech
# [normalize_title] Orijinal: StartUp Fayette – Sent, Not Sold: Make Business Come to You - Peachtree City Citizen
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: startup fayette sent sold make business come
# [normalize_title] Orijinal: NIDA Small Business Grants Support AI Startups - National Institute on Drug Abuse (NIDA) (.gov)
# [normalize_title] Token sayisi: 7
# [normalize_title] Sonuc: nida small business grants support startups
# [normalize_title] Orijinal: Why the next wave of startups won't start with funding - Forbes India
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: next wave startups start funding
# [normalize_title] Orijinal: Why the future of AI depends on human insight - Startups Magazine
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: future depends human insight
# [normalize_title] Orijinal: African fintech is entering a credibility phase, and Payaza’s new ratings show why - Business Insider Africa
# [normalize_title] Token sayisi: 14
# [normalize_title] Sonuc: african fintech entering credibility phase payaza ratings show
# [normalize_title] Orijinal: Ebury, Santander’s International Payments Fintech, Secures c.£550 Million to Accelerate Growth and Global Expansion - Financial IT
# [normalize_title] Token sayisi: 16
# [normalize_title] Sonuc: ebury santander international payments fintech secures million accelerate growth global expansion
# [normalize_title] Orijinal: Tether leads $14M Series A in Argentine crypto fintech belo to scale stablecoins across LatAm - Tech Funding News
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: tether leads 14m series argentine crypto fintech belo scale stablecoins across latam
# [normalize_title] Orijinal: SAS: Using AI Agents to Revolutionise Fraud Detection - FinTech Magazine
# [normalize_title] Token sayisi: 8
# [normalize_title] Sonuc: sas using agents revolutionise fraud detection
# [normalize_title] Orijinal: Southeast Asia emerges as top FinTech hub in Asia - IBS Intelligence
# [normalize_title] Token sayisi: 9
# [normalize_title] Sonuc: southeast asia emerges top fintech hub asia
# [normalize_title] Orijinal: Robinhood, SoFi Stocks Sink After Earnings As Fintech Investors Punish Misses - Benzinga
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: robinhood sofi stocks sink earnings fintech investors punish misses
# [normalize_title] Orijinal: Prediction: This Popular Cryptocurrency Could Hit $0 by Year-End 2026 - Yahoo Finance
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: prediction popular cryptocurrency could hit year end
# [normalize_title] Orijinal: New scam reported in Banks Co. claims phony cryptocurrency kiosks - AccessWDUN
# [normalize_title] Token sayisi: 10
# [normalize_title] Sonuc: scam reported banks claims phony cryptocurrency kiosks
# [normalize_title] Orijinal: Federal government plans to ban crypto ATMs to stop scammers from defrauding Canadians - CBC
# [normalize_title] Token sayisi: 13
# [normalize_title] Sonuc
# [normalize_title] Orijinal: Humanoids will handle your baggage at Tokyo's short-staffed airport - New Atlas
# [normalize_title] Token sayisi: 11
# [normalize_title] Sonuc: humanoids handle baggage tokyo short staffed airport
# [normalize_title] Orijinal: Inforegio - Robotics in Action: explore cross-border R&I in the Interreg Upper Rhine area - European Commission
# [normalize_title] Token sayisi: 15
# [normalize_title] Sonuc: inforegio robotics action explore cross border interreg upper rhine area
# [normalize_title] Orijinal: Bessemer Predicts: Robotics and physical AI - Bessemer Venture Partners
# [normalize_title] Token sayisi: 6
# [normalize_title] Sonuc: bessemer predicts robotics physical
# Normalize kayit sayisi: 2798
# Ornek normalize kayit:
# [{'link': 'https://www.marketwatch.com/bulletins/redirect/go?g=dab30966-8cf2-4a64-ba38-bbf711571f2f&mod=mw_rss_bulletins',
#   'normalized_title': 'stocks clock best month since wall street shakes iran '
#                       'oil shock',
#   'pubDate': '2026-04-30 21:06:53',
#   'source': 'marketwatch',
#   'title': 'U.S. stocks clock best month since 2020 as Wall Street shakes off '
#            'Iran oil shock'},
#  {'link': 'https://us.headtopics.com/news/faa-chief-predicts-fewer-air-traffic-control-delays-this-82875820',
#   'normalized_title': 'faa chief predicts fewer air traffic control delays '
#                       'summer',
#   'pubDate': '2026-04-30 21:06:40',
#   'source': 'headtopics',
#   'title': 'FAA chief predicts fewer air traffic control delays this summer'}]

# %%
write_csv(
    CONFIG['normalized_out_csv'],
    normalized_records,
    fieldnames=['title', 'normalized_title', 'source', 'link', 'pubDate'],
)
write_json(CONFIG['normalized_out_json'], normalized_records)

print(f"Normalize CSV kaydedildi: {CONFIG['normalized_out_csv']}")
print(f"Normalize JSON kaydedildi: {CONFIG['normalized_out_json']}")
# Out:
# [write_csv] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# [write_csv] Satir sayisi: 2798
# [write_csv] Tamamlandi
# [write_json] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json
# [write_json] Kayit sayisi: 2798
# [write_json] Tamamlandi
# Normalize CSV kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# Normalize JSON kaydedildi: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json

# %%
if len(normalized_records) < 2:
    raise ValueError('Yeterli veri yok. En az 2 baslik gerekli.')

titles = [r['normalized_title'] for r in normalized_records]
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
matrix = vectorizer.fit_transform(titles)
sim_matrix = cosine_similarity(matrix)

print(f'TFIDF matrix boyutu: {matrix.shape}')
print(f'Similarity matrix boyutu: {sim_matrix.shape}')
# Out:
# TFIDF matrix boyutu: (2798, 22360)
# Similarity matrix boyutu: (2798, 2798)

# %%
pairs = []
n = len(normalized_records)
threshold = CONFIG['threshold']

for i in range(n):
    for j in range(i + 1, n):
        score = float(sim_matrix[i, j])
        if score < threshold:
            continue

        a = normalized_records[i]
        b = normalized_records[j]
        source_a = (a['source'] or '').strip().lower()
        source_b = (b['source'] or '').strip().lower()
        link_a = (a['link'] or '').strip().lower()
        link_b = (b['link'] or '').strip().lower()

        # Ders kurali: ayni kaynak veya ayni link ise duplicate listesine alma.
        if source_a and source_b and source_a == source_b:
            continue
        if link_a and link_b and link_a == link_b:
            continue

        pairs.append(
            {
                'title_1': a['title'],
                'title_2': b['title'],
                'normalized_title_1': a['normalized_title'],
                'normalized_title_2': b['normalized_title'],
                'similarity': f'{score:.4f}',
                'source_1': a['source'],
                'source_2': b['source'],
                'link_1': a['link'],
                'link_2': b['link'],
                'pubDate_1': a['pubDate'],
                'pubDate_2': b['pubDate'],
            }
        )

print(f'Bulunan duplicate cift sayisi: {len(pairs)}')
print('Ilk 3 sonuc:')
pprint(pairs[:3])
# Out:
# Bulunan duplicate cift sayisi: 161
# Ilk 3 sonuc:
# [{'link_1': 'https://news.mongabay.com/2026/04/in-guatemala-new-ai-technology-will-be-listening-for-illegal-deforestation/',
#   'link_2': 'https://news.google....?oc=5',
#   'normalized_title_1': 'guatemala technology listening illegal deforestation',
#   'normalized_title_2': 'guatemala technology listening illegal deforestation '
#                         'news',
#   'pubDate_1': '2026-04-30 21:05:18',
#   'pubDate_2': 'Thu, 30 Apr 2026 21:06:18 GMT',
#   'similarity': '0.9181',
#   'source_1': 'mongabay',
#   'source_2': 'news - Mongabay',
#   'title_1': 'In Guatemala, new AI technology will be ‘listening’ for illegal '
#              'deforestation',
#   'title_2': 'In Guatemala, new AI technology will be ‘listening’ for illegal '
#              'deforestation - news - Mongabay'},
#  {'link_1': 'https://www.benzinga.com/pressreleases/26/04/g52199923/fairfax-india-holdings-corporation-first-quarter-financial-results',
#   'link_2': 'https://www.globenewswire.com/news-release/2026/04/30/3285558/0/en/Fairfax-India-Holdings-Corporation-First-Quarter-Financial-Results.html',
#   'normalized_title_1': 'fairfax india holdings corporation first quarter '
#                         'financial results',
#   'normalized_title_2': 'fairfax india holdings corporation first quarter '
#                         'financial results',
#   'pubDate_1': '2026-04-30 21:05:00',
#   'pubDate_2': '2026-04-30 21:05:00',
#   'similarity': '1.0000',
#   'source_1': 'benzinga',
#   'source_2': 'globenewswire',
#   'title_1': 'Fairfax India Holdings Corporation: First Quarter Financial '
#              'Results',
#   'title_2': 'Fairfax India Holdings Corporation: First Quarter Financial '
#              'Results'},
#  {'link_1': 'https://utulsa.edu/news/bis-capstone-projects-deliver-technology-solutions-for-tulsa-nonprofits/',
#   'link_2': 'https://news.google.com/rss/articles/CBMinAFBVV95cUxPMThGYXpHUjdMeTRhT3FvdUFnTGYzMjlUT1pNLWJzaEZkOUZ1MHdIODA0blp2V2hFSS1oLWJDeHRNNzlBWUZwN01pcGVTZVNEN2I0eGRtTHRycm5HRFJqS21NdGZXejFmZXF6R2YyWDBiV3lMWWI2VEtvaE92dWRWekcxMGgtQXFKY095QkE1cTVMdjhGd25qZ0pKSmk?oc=5',
#   'normalized_title_1': 'bis capstone projects deliver technology solutions '
#                         'tulsa nonprofits',
#   'normalized_title_2': 'bis capstone projects deliver technology solutions '
#                         'tulsa nonprofits',
#   'pubDate_1': '2026-04-30 21:04:45',
#   'pubDate_2': 'Thu, 30 Apr 2026 21:04:45 GMT',
#   'similarity': '1.0000',
#   'source_1': 'news_utulsa',
#   'source_2': 'The University of Tulsa',
#   'title_1': 'BIS Capstone projects deliver technology solutions for Tulsa '
#              'nonprofits',
#   'title_2': 'BIS Capstone projects deliver technology solutions for Tulsa '
#              'nonprofits - The University of Tulsa'}]

# %%
write_csv(
    CONFIG['pairs_out_csv'],
    pairs,
    fieldnames=[
        'title_1', 'title_2', 'normalized_title_1', 'normalized_title_2', 'similarity',
        'source_1', 'source_2', 'link_1', 'link_2', 'pubDate_1', 'pubDate_2'
    ],
)
write_json(CONFIG['pairs_out_json'], pairs)

print('\n=== PIPELINE OZETI ===')
print(f"Ham kayit sayisi         : {len(raw_records)}")
print(f"Normalize kayit sayisi   : {len(normalized_records)}")
print(f"Esik degeri              : {CONFIG['threshold']:.2f}")
print(f"Duplicate cift sayisi    : {len(pairs)}")
print(f"Normalize CSV            : {CONFIG['normalized_out_csv']}")
print(f"Normalize JSON           : {CONFIG['normalized_out_json']}")
print(f"Duplicate CSV            : {CONFIG['pairs_out_csv']}")
print(f"Duplicate JSON           : {CONFIG['pairs_out_json']}")
# Out:
# [write_csv] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv
# [write_csv] Satir sayisi: 161
# [write_csv] Tamamlandi
# [write_json] Yaziliyor: C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json
# [write_json] Kayit sayisi: 161
# [write_json] Tamamlandi
#
# === PIPELINE OZETI ===
# Ham kayit sayisi         : 2805
# Normalize kayit sayisi   : 2798
# Esik degeri              : 0.85
# Duplicate cift sayisi    : 161
# Normalize CSV            : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.csv
# Normalize JSON           : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\processed\all\headlines_normalized_all.json
# Duplicate CSV            : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.csv
# Duplicate JSON           : C:\Users\musta\OneDrive\Masaüstü\Yapay Zeka Dersi\data\results\all\duplicate_pairs_all.json

# %%
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np

print('[11/11] Zipf kutuphaneleri yuklendi.')
# Out:
# [11/11] Zipf kutuphaneleri yuklendi.

# %%
# Normalize edilmis basliklardan tek bir token listesi olustur.
all_tokens = []
for rec in normalized_records:
    all_tokens.extend((rec.get('normalized_title') or '').split())

if not all_tokens:
    raise ValueError('Zipf analizi icin token bulunamadi.')

# Kelime frekanslarini hesapla.
word_freq = Counter(all_tokens)
sorted_items = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
sorted_freqs = [freq for _, freq in sorted_items]
ranks = np.arange(1, len(sorted_freqs) + 1)

print(f'Toplam token sayisi: {len(all_tokens)}')
print(f'Tekil kelime sayisi: {len(word_freq)}')
print('En sik 15 kelime:')
for word, freq in sorted_items[:15]:
    print(f'  {word}: {freq}')

# Rank-Frequency tablosunun ilk satirlarini goster.
zipf_preview = [
    {'rank': i + 1, 'word': sorted_items[i][0], 'frequency': sorted_items[i][1]}
    for i in range(min(20, len(sorted_items)))
]
pprint(zipf_preview)

# Zipf log-log grafigi.
plt.figure(figsize=(8, 5))
plt.loglog(ranks, sorted_freqs, marker='o', linestyle='none', markersize=3, alpha=0.65)
plt.xlabel('Kelime Sirasi (log)')
plt.ylabel('Frekans (log)')
plt.title('Headlines Verisi Icin Zipf Yasasi')
plt.grid(True, which='both', linestyle='--', alpha=0.3)
plt.show()

# Basit uyum ozeti (ilk N rank icin log-log lineer fit).
fit_n = min(300, len(sorted_freqs))
log_ranks = np.log(ranks[:fit_n])
log_freqs = np.log(np.array(sorted_freqs[:fit_n], dtype=float))
slope, intercept = np.polyfit(log_ranks, log_freqs, 1)
print(f'Log-log egim (ilk {fit_n} rank): {slope:.3f}')
print('Not: Eğim -1 civarına yaklaştıkça klasik Zipf davranışı daha belirgin olur.')
# Out:
# Toplam token sayisi: 21428
# Tekil kelime sayisi: 6619
# En sik 15 kelime:
#   technology: 153
#   stock: 147
#   market: 131
#   global: 118
#   innovation: 111
#   energy: 107
#   quantum: 107
#   space: 104
#   computing: 103
#   cloud: 95
#   business: 94
#   iran: 93
#   world: 88
#   climate: 87
#   software: 87
# [{'frequency': 153, 'rank': 1, 'word': 'technology'},
#  {'frequency': 147, 'rank': 2, 'word': 'stock'},
#  {'frequency': 131, 'rank': 3, 'word': 'market'},
#  {'frequency': 118, 'rank': 4, 'word': 'global'},
#  {'frequency': 111, 'rank': 5, 'word': 'innovation'},
#  {'frequency': 107, 'rank': 6, 'word': 'energy'},
#  {'frequency': 107, 'rank': 7, 'word': 'quantum'},
#  {'frequency': 104, 'rank': 8, 'word': 'space'},
#  {'frequency': 103, 'rank': 9, 'word': 'computing'},
#  {'frequency': 95, 'rank': 10, 'word': 'cloud'},
#  {'frequency': 94, 'rank': 11, 'word': 'business'},
#  {'frequency': 93, 'rank': 12, 'word': 'iran'},
#  {'frequency': 88, 'rank': 13, 'word': 'world'},
#  {'frequency': 87, 'rank': 14, 'word': 'climate'},
#  {'frequency': 87, 'rank': 15, 'word': 'software'},
#  {'frequency': 86, 'rank': 16, 'word': 'healthcare'},
#  {'frequency': 81, 'rank': 17, 'word': 'learning'},
#  {'frequency': 78, 'rank': 18, 'word': 'change'},
#  {'frequency': 78, 'rank': 19, 'word': 'fintech'},
#  {'frequency': 77, 'rank': 20, 'word': 'data'}]
# Log-log egim (ilk 300 rank): -0.628
# Not: Eğim -1 civarına yaklaştıkça klasik Zipf davranışı daha belirgin olur.
